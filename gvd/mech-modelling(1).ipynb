# %%
! pip install -q torch_geometric
! pip install -q cell-gears
! pip install -q pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.6.0+cu124.html
! pip -q install scikit-misc
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 29.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.2 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.1 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 95.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 11.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 53.2 kB/s eta 0:00:00ta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 354.7 kB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 9.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 5.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# ydata-profiling 4.17.0 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.7 which is incompatible.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.7.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.2 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 46.0 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 11.4 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 104.8 MB/s eta 0:00:0000:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 76.8 MB/s eta 0:00:00:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.0/187.0 kB 4.4 MB/s eta 0:00:0000:01

# %%
from gears import PertData
from copy import deepcopy
import os
import pickle
from torch.optim.lr_scheduler import StepLR
from torch import optim
from torch_geometric.data import Data
from torch_geometric.nn import knn_graph
from torch_geometric.loader import DataLoader
from gears.gears import GEARS
from gears.model import GEARS_Model
import anndata as ad
from gears.data_utils import DataSplitter,print_sys
import torch
import scanpy as sc
import random

# %%
class PertData_(PertData):
    def prepare_split(self, split = 'simulation',
                      seed = 1,
                      train_gene_set_size = 0.75,
                      combo_seen2_train_frac = 0.75,
                      combo_single_split_test_set_fraction = 0.1,
                      test_perts = None,
                      only_test_set_perts = False,
                      test_pert_genes = None,
                      split_dict_path=None,
                      val_size=0.1):
        available_splits = ['simulation', 'simulation_single', 'combo_seen0',
                            'combo_seen1', 'combo_seen2', 'single', 'no_test',
                            'no_split', 'custom']
        if split not in available_splits:
            raise ValueError('currently, we only support ' + ','.join(available_splits))
        self.split = split
        self.seed = seed
        self.subgroup = None
        self.val_size = val_size

        if split == 'custom':
            try:
                with open(split_dict_path, 'rb') as f:
                    self.set2conditions = pickle.load(f)
            except:
                    raise ValueError('Please set split_dict_path for custom split')
            return

        self.train_gene_set_size = train_gene_set_size
        split_folder = os.path.join(self.dataset_path, 'splits')
        if not os.path.exists(split_folder):
            os.mkdir(split_folder)
        split_file = self.dataset_name + '_' + split + '_' + str(seed) + '_' \
                                       +  str(train_gene_set_size) + '.pkl'
        split_path = os.path.join(split_folder, split_file)

        if test_perts:
            split_path = split_path[:-4] + '_' + test_perts + '.pkl'

        if os.path.exists(split_path):
            print('here1')
            print_sys("Local copy of split is detected. Loading...")
            set2conditions = pickle.load(open(split_path, "rb"))
            if split == 'simulation':
                subgroup_path = split_path[:-4] + '_subgroup.pkl'
                subgroup = pickle.load(open(subgroup_path, "rb"))
                self.subgroup = subgroup
        else:
            print_sys("Creating new splits....")
            if test_perts:
                test_perts = test_perts.split('_')

            if split in ['simulation', 'simulation_single']:
                # simulation split
                DS = DataSplitter(self.adata, split_type=split)

                adata, subgroup = DS.split_data(train_gene_set_size = train_gene_set_size,
                                                combo_seen2_train_frac = combo_seen2_train_frac,
                                                seed=seed,
                                                test_perts = test_perts,
                                                only_test_set_perts = only_test_set_perts
                                               )
                subgroup_path = split_path[:-4] + '_subgroup.pkl'
                pickle.dump(subgroup, open(subgroup_path, "wb"))
                self.subgroup = subgroup

            elif split[:5] == 'combo':
                # combo perturbation
                split_type = 'combo'
                seen = int(split[-1])

                if test_pert_genes:
                    test_pert_genes = test_pert_genes.split('_')

                DS = DataSplitter(self.adata, split_type=split_type, seen=int(seen))
                adata = DS.split_data(test_size=combo_single_split_test_set_fraction,
                                      test_perts=test_perts,
                                      test_pert_genes=test_pert_genes,
                                      seed=seed)

            elif split == 'single':
                # single perturbation
                DS = DataSplitter(self.adata, split_type=split)
                adata = DS.split_data(test_size=combo_single_split_test_set_fraction,val_size=val_size,
                                      seed=seed)

            elif split == 'no_test':
                # no test set
                DS = DataSplitter(self.adata, split_type=split)
                adata = DS.split_data(seed=seed)

            elif split == 'no_split':
                # no split
                adata = self.adata
                adata.obs['split'] = 'test'

            set2conditions = dict(adata.obs.groupby('split').agg({'condition':
                                                        lambda x: x}).condition)
            set2conditions = {i: j.unique().tolist() for i,j in set2conditions.items()}
            pickle.dump(set2conditions, open(split_path, "wb"))
            print_sys("Saving new splits at " + split_path)

        self.set2conditions = set2conditions

        if split == 'simulation':
            print_sys('Simulation split test composition:')
            for i,j in subgroup['test_subgroup'].items():
                print_sys(i + ':' + str(len(j)))
        print_sys("Done!")


    def load(self, data_name=None, data_path=None):
        ## void return anyways
        print(data_name)
        super().load(data_name, data_path)
        ## finding out hvg index set
        # sc.pp.neighbors(self.adata, n_neighbors=15, use_rep='X')
        # sc.pp.highly_variable_genes(self.adata, n_top_genes=2000, subset=False, flavor='seurat_v3')
        # self.hvg_idx = self.adata.var['highly_variable'].to_numpy().nonzero()[0]
    def get_dataloader(self, batch_size, test_batch_size = None):
        """
        Get dataloaders for training and testing

        Parameters
        ----------
        batch_size: int
            Batch size for training
        test_batch_size: int
            Batch size for testing

        Returns
        -------
        dict
            Dictionary of dataloaders

        """
        if test_batch_size is None:
            test_batch_size = batch_size

        self.node_map = {x: it for it, x in enumerate(self.adata.var.gene_name)}
        self.gene_names = self.adata.var.gene_name

        # Create cell graphs
        cell_graphs = {}
        if self.split == 'no_split':
            i = 'test'
            cell_graphs[i] = []
            for p in self.set2conditions[i]:
                if p != 'ctrl':
                    cell_graphs[i].extend(self.dataset_processed[p])

            print_sys("Creating dataloaders....")
            # Set up dataloaders
            test_loader = DataLoader(cell_graphs['test'],
                                batch_size=batch_size, shuffle=False)

            print_sys("Dataloaders created...")
            return {'test_loader': test_loader}
        else:
            if self.split =='no_test':
                splits = ['train','val']
            else:
                splits = ['train','val','test']
            print(self.set2conditions)
            for i in splits:
                cell_graphs[i] = []
                if i in self.set2conditions:
                    for p in self.set2conditions[i]:
                        cell_graphs[i].extend(self.dataset_processed[p])
            # print(cell_graphs)
            print_sys("Creating dataloaders....")

            # Set up dataloaders
            if(len(cell_graphs["val"]) == 0):
                ## give a subset of entries to val from train.
                shuffled_list = cell_graphs["train"].copy()
                random.shuffle(shuffled_list)
                split_index = int(self.val_size*len(shuffled_list))
                cell_graphs["val"] = shuffled_list[:split_index]
                cell_graphs["train"] = shuffled_list[split_index:]



            train_loader = DataLoader(cell_graphs['train'],
                                batch_size=batch_size, shuffle=True, drop_last = True)
            if len(cell_graphs["val"])>0:
                val_loader = DataLoader(cell_graphs['val'],
                                    batch_size=batch_size, shuffle=True)
            else:
                val_loader = None
            if len(cell_graphs["test"])>0:
                test_loader = DataLoader(cell_graphs['val'],
                                    batch_size=batch_size, shuffle=True)
            else:
                test_loader = None

            if self.split !='no_test':
                test_loader = DataLoader(cell_graphs['test'],
                                batch_size=batch_size, shuffle=False)
                self.dataloader =  {'train_loader': train_loader,
                                    'val_loader': val_loader,
                                    'test_loader': test_loader}

            else:
                self.dataloader =  {'train_loader': train_loader,
                                    'val_loader': val_loader}
            print_sys("Done!")

# %%
from torch import nn
import torch
from torch import nn
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv
from torch_geometric.utils import coalesce
class Gated_Addition(nn.Module):
    def __init__(self,vector_dim:int):
        super().__init__()
        self.gating = nn.Linear(2*vector_dim,vector_dim)
    def forward(self,x1,x2):
        g = self.gating(torch.concat((x1,x2),dim=-1))
        return g*x1 + (1-g)*x2

# lowrank_perturber_sage.py


class SAGEEncoder(nn.Module):
    """
    Small GraphSAGE node encoder.
    """
    def __init__(self, x_dim, hidden, out, layers=2, dropout=0.0, normalize=False):
        super().__init__()
        dims = [x_dim] + [hidden]*(layers-1) + [out]
        self.convs = nn.ModuleList([SAGEConv(dims[i], dims[i+1]) for i in range(len(dims)-1)])
        self.dropout = dropout
        self.normalize = normalize
        self.bns = nn.ModuleList([nn.BatchNorm1d(d) for d in dims[1:-1]]) if layers > 1 else None
        print(f"Expected Dimensions of activations through encoder: {dims}")
    def forward(self, x, edge_index):
        h = x
        L = len(self.convs)
        for i, conv in enumerate(self.convs):
            h = conv(h, edge_index)
            if i < L - 1:
                h = F.relu(h)
                if self.bns is not None:
                    h = self.bns[i](h)
                if self.dropout > 0:
                    h = F.dropout(h, p=self.dropout, training=self.training)
        if self.normalize:
            h = F.normalize(h, p=2, dim=-1,eps=1e-8)
        return h

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.utils import coalesce
# Assuming SAGEEncoder is defined elsewhere
# from your_project.encoders import SAGEEncoder

class AttentionalPerturber(nn.Module):
    """
    Predicts edge deltas using a GAT-like additive attention mechanism.

      h = SAGE(x, edge_index)
      h_z = concat(h, z_broadcasted_to_nodes)
      
      score_u = AttnLinear_Left(h_z)
      score_v = AttnLinear_Right(h_z)
      
      Δ_{uv} = LeakyReLU(score_u[u] + score_v[v])
      w' = softplus( w + λ * Δ )
    """
    def __init__(self,
                 x_dim: int,
                 z_dim: int,
                 enc_hidden: int = 128,
                 enc_out: int = 128,
                 enc_layers: int = 2,
                 enc_dropout: float = 0.0,
                 enc_l2norm: bool = False,
                 nonneg: bool = True,
                 symmetric: bool = True,
                 lambda_init: float = 0.5):
        super().__init__()
        self.encoder = SAGEEncoder(x_dim, enc_hidden, enc_out,
                                   layers=enc_layers,
                                   dropout=enc_dropout,
                                   normalize=enc_l2norm)

        # Input to attention heads is node embedding + global z
        attn_in_dim = enc_out + z_dim
        
        # We use separate linear layers for source (left) and target (right)
        # This allows for asymmetric interactions (e.g., GATv2 style)
        self.attn_l = nn.Linear(attn_in_dim, 1, bias=False)
        self.attn_r = nn.Linear(attn_in_dim, 1, bias=False)
        self.leaky_relu = nn.LeakyReLU(0.2)

        self.nonneg = nonneg
        self.symmetric = symmetric
        self.lambda_scale = nn.Parameter(torch.tensor(lambda_init, dtype=torch.float32))
        
        # Note: We ignore the original weight `w` in this formulation,
        # but you could easily add it to `attn_in_dim` if needed
        # by first creating edge features. This is the simpler node-centric version.

    @staticmethod
    def _symmetrize(edge_index, w, reduce: str = "mean"):
        # (Copied from your original class)
        ei, w_sum = coalesce(edge_index, w, reduce="add")
        ones = torch.ones_like(w)
        _, count = coalesce(edge_index, ones, reduce="add")
        if reduce == "mean":
            w_sym = w_sum / count.clamp_min(1)
        elif reduce == "sum":
            w_sym = w_sum
        else:
            raise ValueError("reduce must be 'mean' or 'sum'")
        return ei, w_sym

    def forward(self,
                x: torch.Tensor,             # [N, x_dim]
                edge_index: torch.Tensor,     # [2, E]
                w: torch.Tensor,              # [E]
                z: torch.Tensor               # [z_dim]
                ):
        # 1) Node embeddings
        h = self.encoder(x, edge_index)       # [N, enc_out]
        N = h.size(0)

        # 2) Combine node features with global perturbation z
        z_b = z.expand(N, -1)                 # [N, z_dim]
        h_z = torch.cat([h, z_b], dim=-1)     # [N, enc_out + z_dim]

        # 3) Get attention scores for all nodes
        scores_l = self.attn_l(h_z)           # [N, 1]
        scores_r = self.attn_r(h_z)           # [N, 1]

        # 4) Compute edge deltas by summing endpoint scores
        u, v = edge_index[0], edge_index[1]   # [E]
        delta_scores = scores_l[u] + scores_r[v]  # [E, 1]
        delta = self.leaky_relu(delta_scores).squeeze(-1) # [E]

        # 5) Apply and post-process
        w_prime = w + self.lambda_scale * delta
        if self.nonneg:
            w_prime = F.softplus(w_prime)

        if self.symmetric:
            edge_index, w_prime = self._symmetrize(edge_index, w_prime, reduce="mean")
            _, delta = self._symmetrize(edge_index, delta, reduce="mean")
            return edge_index, w_prime, delta

        return edge_index, w_prime, delta

# %%
class GEARS_No_Coexpress(GEARS_Model):
    def __init__(self, args):
        super().__init__(args)
        self.layers_emb_pos = torch.nn.ModuleList() # Empty module list

# %%
class GEARS_No_Coexpress(GEARS_Model):
    def __init__(self, args):
        super().__init__(args)
        self.layers_emb_pos = torch.nn.ModuleList() # Empty module list

# %%
from torch_geometric.data import Data, Batch
class GEARS_MECH(GEARS_Model):
    def __init__(self, args):
        super().__init__(args)
        self.pretrain_phase = None
        hidden_size = args['hidden_size']
        self.return_graphs = False
        low_rank_percent = 0.2 ## make this something thats in the config.
        ## adding the gated expression embedding module
        self.expression_projection = nn.Linear(1,args["hidden_size"])
        self.gating = Gated_Addition(vector_dim=args["hidden_size"])
        ## adding self.graph_perturber
        r = int(low_rank_percent*self.G_coexpress.shape[1])
        print(f"Downprojected Rank {r}")
        ## it takes the gene-embeddings as an input
        ## i mean it uses the gener graph
        ## so x_dim is embedding_dim, ie: hidden_size in the args , same for the pert_dim ie: z_dim
        self.graph_perturber = AttentionalPerturber(
            x_dim=hidden_size, z_dim= hidden_size,
        )
        ## other args used in the above init:
        # enc_hidden: int = 128,
        # enc_out: int = 128,
        # enc_layers: int = 2,
        # enc_dropout: float = 0.0,
        # enc_l2norm: bool = False,
        # nonneg: bool = True,
        # symmetric: bool = True,
        # lambda_init: float = 0.5


        ## will have to be a module, that takes in an edge_weights, a learnable perturbation embedding, and outputs a changed/perturbed graph index of the same dimension.

    def forward(self, data):
        """
        Forward pass of the model
        """
        x, pert_idx = data.x, data.pert_idx
        num_graphs = len(data.batch.unique()) # each cell has its own graph
        ## get base gene embeddings, num_batch of the same graph.
        emb = self.gene_emb(torch.LongTensor(list(range(self.num_genes))).repeat(num_graphs, ).to(self.args['device']))
        emb = self.bn_emb(emb)
        base_emb = self.emb_trans(emb)

        ## EXPRESSION EMBEDDING MODULE, TO EMBED CELL EXPRESSION.
        x_cells = x.view(num_graphs, self.num_genes, 1)
        means   = x_cells.mean(dim=0, keepdim=True)  # (1, G, 1)
        centered= x_cells - means                    # (B, G, 1)
        # back to (B*G, 1) for linear
        centered = centered.view(-1, 1)
        expr_emb = self.expression_projection(centered)  # (B*G, H)
        base_emb = self.gating(base_emb,expr_emb)

        #
        if not self.pretrain_phase:
            ### START OF BLOCK FOR THIS
            pert_global_emb = self.pert_emb(torch.LongTensor(list(range(self.num_perts))).to(self.args['device']))
            ## augment global perturbation embedding with GNN
            ## pass the perturbation global embedding through gnn
            for idx, layer in enumerate(self.sim_layers):
                # GCN with Perturbation graph constructed via Gene-Ontology Network
                pert_global_emb = layer(pert_global_emb, self.G_sim, self.G_sim_weight)
                if idx < self.num_layers - 1:
                    pert_global_emb = pert_global_emb.relu()
            pert_index = []
            for idx, i in enumerate(pert_idx):
                for j in i:
                    if j != -1:
                        ## j = -1 is the control perturbation index, dunno why they arent appending it
                        ## idx indicates which cell, j corresponds to the perturbation number.
                        pert_index.append([idx, j])
            pert_index = torch.tensor(pert_index).T ## 2 x numgraohs with (cell_id, pert_id)
            base_emb = base_emb.reshape(num_graphs, self.num_genes, -1)

            if pert_index.shape[0] != 0:
                ### in case all samples in the batch are controls, then there is no indexing for pert_index.
                pert_track = {}
                ## i is index of that cell in the batch, j is the perturbation index/type ?
                ## pert_index[0] is the cell_id
                for i, j in enumerate(pert_index[0]):
                    if j.item() in pert_track:
                        ## to pert_track, add the perturbation embedding for that perturbation, which is in pert_index[1][i]
                        pert_track[j.item()] = pert_track[j.item()] + pert_global_emb[pert_index[1][i]]
                        ## pert_track[cell_id] = pert_track[cell_id] + pert_global[pert_id corresponding to cell_id ]
                    else:
                        pert_track[j.item()] = pert_global_emb[pert_index[1][i]]

                # print(f"This is pert_track{pert_track}")

                ## Edge index will remain the same, only the edge weights will change.

                all_edge_weights = {}

                if len(list(pert_track.values())) > 0:
                    if len(list(pert_track.values())) == 1:
                        # circumvent when batch size = 1 with single perturbation and cannot feed into MLP
                        emb_total = self.pert_fuse(torch.stack(list(pert_track.values()) * 2))
                    else:
                        ## pass this specific perturbation embedding set through an mlp for it to add to the base embedding
                        emb_total = self.pert_fuse(torch.stack(list(pert_track.values())))

                    for idx, j in enumerate(pert_track.keys()):
                        ## j is cell_id, ie: which graph we're adding this to, and emb_total[idx] has the perturbation embedding that we're adding to that corresponding cell
                        ##
                        node_embs = base_emb[j]
                        pert_emb = emb_total[idx]
                        edge_index, w_prime, delta = self.graph_perturber(node_embs, self.G_coexpress, self.G_coexpress_weight, pert_emb)
                        all_edge_weights[j] = w_prime

        pos_emb = self.emb_pos(torch.LongTensor(list(range(self.num_genes))).repeat(num_graphs, ).to(self.args['device']))
        data_list = []
        # print(f"This is all_edge_weights {all_edge_weights}")
        ## one hot vector to tell if its a control or not
        ctrl_no_ctrl = torch.zeros(num_graphs,1).to(self.args['device'])
        for i in range(num_graphs):
            node_features = pos_emb[i * self.num_genes : (i + 1) * self.num_genes]
            # print(f"Node feature dim: {node_features.shape}")
            if i in all_edge_weights:
                ## special graph corresponding to perturbed edges
                data_list.append(
                    Data(
                        x=node_features,  # Node features for graph i
                        edge_index=self.G_coexpress, # Same structure
                        edge_weight=all_edge_weights[i] # DIFFERENT weights
                    )
                )
                ctrl_no_ctrl[i] = 1.0
            else:
                ## control cells 
                data_list.append(
                    Data(
                        x=node_features,  # Node features for graph i
                        edge_index=self.G_coexpress, # Same structure
                        edge_weight= self.G_coexpress_weight
                    )
                )
        
        batch = Batch.from_data_list(data_list)
        batch = batch.to(self.args["device"])
        for idx, layer in enumerate(self.layers_emb_pos):
            batch.x = layer(batch.x, batch.edge_index, batch.edge_weight)
            if idx < len(self.layers_emb_pos) - 1:
                batch.x = batch.x.relu()
        final_pos_emb = batch.x.view(num_graphs, self.num_genes, -1)
        base_emb = base_emb + 0.7 * final_pos_emb
        base_emb = base_emb.reshape(num_graphs*self.num_genes,-1)
        base_emb = self.emb_trans_v2(base_emb)
        base_emb = base_emb.reshape(num_graphs * self.num_genes, -1)
        base_emb = self.bn_pert_base(base_emb)
        base_emb = self.transform(base_emb)
        out = self.recovery_w(base_emb)
        out = out.reshape(num_graphs, self.num_genes, -1)
        out = out.unsqueeze(-1) * self.indv_w1
        w = torch.sum(out, axis = 2)
        out = w + self.indv_b1
        cross_gene_embed = self.cross_gene_state(out.reshape(num_graphs, self.num_genes, -1).squeeze(2))
        cross_gene_embed = cross_gene_embed.repeat(1, self.num_genes)
        cross_gene_embed = cross_gene_embed.reshape([num_graphs,self.num_genes, -1])
        cross_gene_out = torch.cat([out, cross_gene_embed], 2)
        cross_gene_out = cross_gene_out * self.indv_w2
        cross_gene_out = torch.sum(cross_gene_out, axis=2)
        out = cross_gene_out + self.indv_b2
        out = out.reshape(num_graphs * self.num_genes, -1)  + x.reshape(-1,1) 
        out = torch.split(torch.flatten(out), self.num_genes)
        if self.return_graphs:
            graph_data =   {"graphs": data_list,
                            "graph_metadata": ctrl_no_ctrl
                            }
            return out, graph_data
            
        return torch.stack(out)
    def compute_graphs(self,data):
        self.return_graphs = True
        with torch.no_grad():
            out, graph_data = self.forward(data)
        self.return_graphs = False
        return out,graph_data

# %%
from gears import GEARS
import numpy as np
from gears.utils import loss_fct
from torch import nn
from gears.utils import  get_similarity_network,GeneSimNetwork
from gears.utils import loss_fct
from gears.inference import *
import numpy as np
from gears.inference import evaluate,compute_metrics
from copy import deepcopy
import pandas as pd
from gears.utils import np_pearson_cor
import networkx as nx
from functools import reduce
import operator
import torch
from functools import reduce
from tqdm import tqdm
import networkx as nx
import torch
import numpy as np
import pandas as pd
from functools import reduce
import operator
from tqdm.auto import tqdm # Import tqdm


class GeneSimNetworkKHops():
    """
    GeneSimNetwork class

    Args:
        edge_list (pd.DataFrame): edge list of the network
        gene_list (list): list of gene names
        node_map (dict): dictionary mapping gene names to node indices
    """
    def __init__(self, edge_list, gene_list, node_map):
        """
        Initialize GeneSimNetwork class
        """
        self.edge_list = edge_list
        self.gene_list = gene_list
        self.node_map = node_map
        self.G = nx.from_pandas_edgelist(self.edge_list, source='source',
                        target='target', edge_attr=['importance'],
                        create_using=nx.DiGraph())
        for n in self.gene_list:
            if n not in self.G.nodes():
                self.G.add_node(n)
        self._update_tensors()

    def _update_tensors(self):
        """Helper to regenerate tensors from the current nx.Graph state."""
        if not self.G.edges:
            self.edge_index = torch.empty((2, 0), dtype=torch.long)
            self.edge_weight = torch.empty((0,), dtype=torch.float)
            return

        # print(self.node_map)
        # print(self.G.edges)
        edge_index_ = [(self.node_map[e[0]], self.node_map[e[1]]) for e in self.G.edges]
        self.edge_index = torch.tensor(edge_index_, dtype=torch.long).T

        edge_attr = nx.get_edge_attributes(self.G, 'importance')
        importance = np.array([edge_attr[e] for e in self.G.edges])
        self.edge_weight = torch.Tensor(importance)

    # --- UPDATED METHOD ---

    def add_zero_weight_khop_edges(self, k, m):
        """
        For each node, finds all nodes reachable within k-hops. From this set,
        it calculates the max-multiplicative-strength path for each.
        It then adds 'm' zero-weight edges to the unconnected nodes with
        the highest strength.

        Args:
            k (int): The maximum hop distance to search.
            m (int): The number of new edges to add per node.
        """
        if k <= 0:
            print("k must be a positive integer.")
            return

        # Changed print statement
        print(f"Graph modification in progress. Original edge count: {len(self.edge_index[0])}")
        new_edges_to_add = []

        # Added tqdm wrapper to the main loop
        for start_node in tqdm(list(self.G.nodes()), desc="Processing nodes"):
            potential_edges = []

            # 1. OPTIMIZATION: Get the subgraph of all nodes reachable
            #    within k hops using nx.ego_graph.
            ego_graph = nx.ego_graph(self.G, n=start_node, radius=k)

            # 2. Iterate ONLY over this smaller set of reachable nodes
            for target_node in ego_graph.nodes():
                # Exclude self-loops and existing direct edges
                if start_node == target_node or self.G.has_edge(start_node, target_node):
                    continue

                # 3. Find all simple paths (this is the required slow part)
                #    We still search on the *original graph* (self.G)
                paths = nx.all_simple_paths(self.G,
                                            source=start_node,
                                            target=target_node,
                                            cutoff=k)

                max_strength = 0.0
                for path in paths:
                    if len(path) > 1:
                        # Calculate multiplicative strength
                        strength = reduce(operator.mul,
                                        (self.G[u][v]['importance'] for u, v in zip(path[:-1], path[1:])))
                        if strength > max_strength:
                            max_strength = strength

                # If a path was found, store this as a potential edge
                if max_strength > 0:
                    potential_edges.append((target_node, max_strength))

            # 4. Sort potential edges by their calculated strength
            potential_edges.sort(key=lambda x: x[1], reverse=True)

            # 5. Add the top 'm' new edges
            for target_node, _ in potential_edges[:m]:
                new_edges_to_add.append((start_node, target_node, {'importance': 0.0}))

        # 6. Add all new edges to the graph at once
        self.G.add_edges_from(new_edges_to_add)
        print(f"Added {len(new_edges_to_add)} new zero-weight edges.")

        # 7. Regenerate tensors to reflect the new graph structure
        self._update_tensors()
        print(f"Tensors updated. New edge count: {len(self.edge_index[0])}")

# %%
from gears.inference import deeper_analysis,non_dropout_analysis
# def get_perturbation_graphs(self,

class GEARS_PRETRAIN(GEARS):
    def __init__(self, pert_data, device='cuda', weight_bias_track=False, proj_name='GEARS', exp_name='GEARS'):

        self.weight_bias_track = weight_bias_track

        if self.weight_bias_track:
            import wandb
            wandb.init(project=proj_name, name=exp_name)
            self.wandb = wandb
        else:
            self.wandb = None

        self.device = device
        self.config = None

        self.dataloader = pert_data.dataloader ##
        self.adata = pert_data.adata
        self.node_map = pert_data.node_map
        self.node_map_pert = pert_data.node_map_pert
        self.data_path = pert_data.data_path
        self.dataset_name = pert_data.dataset_name
        self.split = pert_data.split
        self.seed = pert_data.seed
        self.train_gene_set_size = pert_data.train_gene_set_size
        self.set2conditions = pert_data.set2conditions
        self.subgroup = pert_data.subgroup
        self.gene_list = pert_data.gene_names.values.tolist()
        self.pert_list = pert_data.pert_names.tolist()
        self.num_genes = len(self.gene_list)
        self.num_perts = len(self.pert_list)
        self.default_pert_graph = pert_data.default_pert_graph
        self.saved_pred = {}
        self.saved_logvar_sum = {}

        self.ctrl_expression = torch.tensor(
            np.mean(self.adata.X[self.adata.obs.condition.values == 'ctrl'],
                    axis=0)).reshape(-1, ).to(self.device)
        pert_full_id2pert = dict(self.adata.obs[['condition_name', 'condition']].values)
        self.dict_filter = {pert_full_id2pert[i]: j for i, j in
                            self.adata.uns['non_zeros_gene_idx'].items() if
                            i in pert_full_id2pert}
        self.ctrl_adata = self.adata[self.adata.obs['condition'] == 'ctrl']

        gene_dict = {g:i for i,g in enumerate(self.gene_list)}
        self.pert2gene = {p: gene_dict[pert] for p, pert in
                            enumerate(self.pert_list) if pert in self.gene_list}
        self.hvg_idx = getattr(pert_data,"hvg_idx", None)

    def update(self,
                pert_data):
        ''' Function to update the pert_data the model is using, ie to switch from control pert_data to perturbed pert_data. '''
        self.dataloader = pert_data.dataloader ##
        self.adata = pert_data.adata
        self.node_map = pert_data.node_map
        self.node_map_pert = pert_data.node_map_pert
        self.data_path = pert_data.data_path
        self.dataset_name = pert_data.dataset_name
        self.split = pert_data.split
        self.seed = pert_data.seed
        self.train_gene_set_size = pert_data.train_gene_set_size
        self.set2conditions = pert_data.set2conditions
        self.subgroup = pert_data.subgroup
        self.gene_list = pert_data.gene_names.values.tolist()
        self.pert_list = pert_data.pert_names.tolist()
        self.num_genes = len(self.gene_list)
        self.num_perts = len(self.pert_list)
        self.default_pert_graph = pert_data.default_pert_graph
        self.saved_pred = {}
        self.saved_logvar_sum = {}
        self.ctrl_expression = torch.tensor(
            np.mean(self.adata.X[self.adata.obs.condition.values == 'ctrl'],
                    axis=0)).reshape(-1, ).to(self.device)
        pert_full_id2pert = dict(self.adata.obs[['condition_name', 'condition']].values)
        self.dict_filter = {pert_full_id2pert[i]: j for i, j in
                            self.adata.uns['non_zeros_gene_idx'].items() if
                            i in pert_full_id2pert}
        self.ctrl_adata = self.adata[self.adata.obs['condition'] == 'ctrl']

        gene_dict = {g:i for i,g in enumerate(self.gene_list)}
        self.pert2gene = {p: gene_dict[pert] for p, pert in
                            enumerate(self.pert_list) if pert in self.gene_list}
        self.hvg_idx = getattr(pert_data,"hvg_idx", None)


        ## calculating co expression similarity graph
        edge_list = {}
        edge_list["coexpress"] = get_similarity_network(network_type='co-express',
                                            adata=self.adata,
                                            threshold=self.graph_config["coexpress_threshold"],
                                            k=self.graph_config["num_similar_genes_co_express_graph"],
                                            data_path=self.data_path,
                                            data_name=self.dataset_name,
                                            split=self.split, seed=self.seed,
                                            train_gene_set_size=self.train_gene_set_size,
                                            set2conditions=self.set2conditions)
        ## checking if multi-hop
        if self.config["num_hops"] > 1:
            sim_network = GeneSimNetworkKHops(edge_list["coexpress"],self.pert_list,self.node_map)
            sim_network.add_zero_weight_khop_edges(
                k=self.config["num_hops"],
                m=self.config["num_add"],)
        else:
            sim_network = GeneSimNetwork(edge_list["coexpress"], self.pert_list, node_map = self.node_map_pert)
        self.config['G_coexpress'] = sim_network.edge_index
        self.config['G_coexpress_weight'] = sim_network.edge_weight
        edge_list["coexpress"] = get_similarity_network(network_type='go',
                                        adata=self.adata,
                                        threshold=self.graph_config["coexpress_threshold"],
                                        k=self.graph_config["num_similar_genes_go_graph"],
                                        pert_list=self.pert_list,
                                        data_path=self.data_path,
                                        data_name=self.dataset_name,
                                        split=self.split, seed=self.seed,
                                        train_gene_set_size=self.train_gene_set_size,
                                        set2conditions=self.set2conditions,
                                        default_pert_graph=self.default_pert_graph)

        self.config['G_go'] = sim_network.edge_index
        self.config['G_go_weight'] = sim_network.edge_weight




    def model_initialize(self, hidden_size = 64,
                            num_go_gnn_layers = 1,
                            num_gene_gnn_layers = 1,
                            decoder_hidden_size = 16,
                            num_similar_genes_go_graph = 20,
                            num_similar_genes_co_express_graph = 20,
                            coexpress_threshold = 0.4,
                            uncertainty = False,
                            uncertainty_reg = 1,
                            direction_lambda = 1e-1,
                            G_go = None,
                            G_go_weight = None,
                            G_coexpress = None,
                            G_coexpress_weight = None,
                            no_perturb = False,
                            gears_model=0,
                            num_hops=1,
                            num_add=1,
                            num_heads=4,
                            gated=False,
                            **kwargs
                        ):

        """
        Initialize the model

        Parameters
        ----------
        hidden_size: int
            hidden dimension, default 64
        num_go_gnn_layers: int
            number of GNN layers for GO graph, default 1
        num_gene_gnn_layers: int
            number of GNN layers for co-expression gene graph, default 1
        decoder_hidden_size: int
            hidden dimension for gene-specific decoder, default 16
        num_similar_genes_go_graph: int
            number of maximum similar K genes in the GO graph, default 20
        num_similar_genes_co_express_graph: int
            number of maximum similar K genes in the co expression graph, default 20
        coexpress_threshold: float
            pearson correlation threshold when constructing coexpression graph, default 0.4
        uncertainty: bool
            whether or not to turn on uncertainty mode, default False
        uncertainty_reg: float
            regularization term to balance uncertainty loss and prediction loss, default 1
        direction_lambda: float
            regularization term to balance direction loss and prediction loss, default 1
        G_go: scipy.sparse.csr_matrix
            GO graph, default None
        G_go_weight: scipy.sparse.csr_matrix
            GO graph edge weights, default None
        G_coexpress: scipy.sparse.csr_matrix
            co-expression graph, default None
        G_coexpress_weight: scipy.sparse.csr_matrix
            co-expression graph edge weights, default None
        no_perturb: bool
            predict no perturbation condition, default False
        gears_model: int
            0- original model, 1- expression embedding, 2 - GAT, 3 - TransformerConv, 4- No Coexpression 5- No perturbation.
        num_hops:int
            1- No additional zero weight edges will be added, else num_hops represents the max number of hops a target node is away from the source node, for us to consider adding a zero-weight edge between source-target
        num_add:int,
            1- Max number of edges of the above type we add for each node
        gated: bool
            Boolean expression that represents as to whether we're gating the expression embedding being added to the base embedding.

        Returns
        -------
        None
        """

        self.config = {
            'hidden_size': hidden_size,
            'num_go_gnn_layers' : num_go_gnn_layers,
            'num_gene_gnn_layers' : num_gene_gnn_layers,
            'decoder_hidden_size' : decoder_hidden_size,
            'num_similar_genes_go_graph' : num_similar_genes_go_graph,
            'num_similar_genes_co_express_graph' : num_similar_genes_co_express_graph,
            'coexpress_threshold': coexpress_threshold,
            'uncertainty' : uncertainty,
            'uncertainty_reg' : uncertainty_reg,
            'direction_lambda' : direction_lambda,
            'G_go': G_go,
            'G_go_weight': G_go_weight,
            'G_coexpress': G_coexpress,
            'G_coexpress_weight': G_coexpress_weight,
            'device': self.device,
            'num_genes': self.num_genes,
            'num_perts': self.num_perts,
            'no_perturb': no_perturb,
            'gears_model': gears_model,
            "num_hops":num_hops,
            "num_add":num_add,
            'num_heads': num_heads,
            'gated':gated
        }

        self.graph_config = {
            "threshold":coexpress_threshold,
            "k_coexpress":num_similar_genes_co_express_graph,
            "k_go":num_similar_genes_go_graph
        }
        if self.wandb:
            self.wandb.config.update(self.config)

        if self.config['G_coexpress'] is None:
            ## calculating co expression similarity graph
            edge_list = get_similarity_network(network_type='co-express',
                                                adata=self.adata,
                                                threshold=coexpress_threshold,
                                                k=num_similar_genes_co_express_graph,
                                                data_path=self.data_path,
                                                data_name=self.dataset_name,
                                                split=self.split, seed=self.seed,
                                                train_gene_set_size=self.train_gene_set_size,
                                                set2conditions=self.set2conditions)
            ## checking if multi-hop
            if self.config["num_hops"] > 1:
                sim_network = GeneSimNetworkKHops(edge_list,self.pert_list,self.node_map)
                sim_network.add_zero_weight_khop_edges(
                    k=self.config["num_hops"],
                    m=self.config["num_add"],)
            else:
                sim_network = GeneSimNetwork(edge_list, self.pert_list, node_map = self.node_map)

            # sim_network = GeneSimNetwork(edge_list, self.gene_list, node_map = self.node_map)
            self.config['G_coexpress'] = sim_network.edge_index
            self.config['G_coexpress_weight'] = sim_network.edge_weight

        if self.config['G_go'] is None:
            ## calculating gene ontology similarity graph
            edge_list = get_similarity_network(network_type='go',
                                                adata=self.adata,
                                                threshold=coexpress_threshold,
                                                k=num_similar_genes_go_graph,
                                                pert_list=self.pert_list,
                                                data_path=self.data_path,
                                                data_name=self.dataset_name,
                                                split=self.split, seed=self.seed,
                                                train_gene_set_size=self.train_gene_set_size,
                                                set2conditions=self.set2conditions,
                                                default_pert_graph=self.default_pert_graph)

            self.config['G_go'] = sim_network.edge_index
            self.config['G_go_weight'] = sim_network.edge_weight

        if self.config["gears_model"] == 0 :
            self.model = GEARS_Model(self.config).to(self.device)
        elif self.config["gears_model"] == 1:
            self.model = GEARS_MECH(self.config).to(self.device)
        #     self.model = GEARS_EMBED(self.config).to(self.device)
        # elif self.config["gears_model"] == 2:
        #     self.model = GEARS_GAT(self.config).to(self.device)
        # elif self.config["gears_model"] == 3:
        #     self.model = GEARS_Transformer(self.config).to(self.device)
        elif self.config["gears_model"] == 4:
            self.model = GEARS_No_Coexpress(self.config).to(self.device)
        # elif self.config["gears_model"] == 5:
        #     self.model = GEARS_No_Perturb(self.config).to(self.device)
        # elif self.config["gears_model"] == 6:
        #     self.model = GEARS_SelfAttn(self.config).to(self.device)
        # elif self.config["gears_model"] == 7:
        #     self.model = GEARS_CELL(self.config).to(self.device)
        # elif self.config["gears_model"] == 8:
        #     self.model = VariantTiny(self.config).to(self.device)
        # elif self.config["gears_model"] == 9:
        #     self.model = Variant(self.config).to(self.device)

        self.best_model = deepcopy(self.model)

    def pretrain_ctrl(self, epochs = 20,
                lr = 1e-3,
                weight_decay = 5e-4
                ):
        train_loader = self.dataloader['train_loader']
        val_loader = self.dataloader['val_loader']

        print(f"Length of train_loader: {len(train_loader)}")
        print(f"Length of val_loader {len(val_loader)}")

        ## This will change the model's forward, to reconstruction only

        self.model.pretrain_phase = True

        self.model = self.model.to(self.device)
        best_model = deepcopy(self.model)
        optimizer = optim.Adam(self.model.parameters(), lr=lr, weight_decay = weight_decay)
        scheduler = StepLR(optimizer, step_size=1, gamma=0.5)
        min_val = np.inf
        print_sys('Start Training...')
        hvg_idx = self.hvg_idx
        for epoch in range(epochs):
            self.model.train()
            for step, batch in enumerate(train_loader):
                batch.to(self.device)
                optimizer.zero_grad()
                y = batch.y
                x = batch.x
                pred = self.model(batch)
                ## autoencoder style loss with directionality enforced.
                ## Consider switching to MSE instead ?
                loss = loss_fct(pred, x, batch.pert,
                                ctrl = self.ctrl_expression,
                                dict_filter = self.dict_filter,
                                direction_lambda = self.config['direction_lambda'])
                loss.backward()
                nn.utils.clip_grad_value_(self.model.parameters(), clip_value=1.0)
                optimizer.step()
                if self.wandb:
                    self.wandb.log({'training_loss': loss.item()})
                if step % 50 == 0:
                    log = "Epoch {} Step {} Train Loss: {:.4f}"
                    print_sys(log.format(epoch + 1, step + 1, loss.item()))
            scheduler.step()
            train_run = evaluate(train_loader,self.model,False,self.device)
            val_run = evaluate(val_loader,self.model,False,self.device)
            ## computing metrics :
            try:
                train_metrics, _ = compute_metrics(train_run)
                val_metrics, _ = compute_metrics(val_run)
                ## print epoch performance
                log = "Epoch {}: Train Overall MSE: {:.4f} " \
                        "Validation Overall MSE: {:.4f}. "
                print_sys(log.format(epoch + 1, train_metrics['mse'],
                                    val_metrics['mse']))
                if(min_val > val_metrics["mse"]):
                    print(f"New Best model has val_mse: {val_metrics['mse']}")
                    self.best_model = deepcopy(self.model)
            except Exception as e:
                print(f"Error while computing metrics: {e}")
            ## computing loss on the highly variable gene set.
            ## computing validation loss of the validation dataloader ?
            ## consider adding evaluation for reconstruction via the autoencoder over here ?
        print(f"Best Val Loss: {min_val}")
        print("Done Training ....")

    def train(self, epochs = 20,
                lr = 1e-3,
                weight_decay = 5e-4
                ):
        print("Training Phase with perturbing graph .....")

        self.model.pretrain_phase = False

        train_loader = self.dataloader['train_loader']
        val_loader = self.dataloader['val_loader']
        print(f"Length of train_loader: {len(train_loader)}")
        print(f"Length of val_loader {len(val_loader)}")
        self.model = self.model.to(self.device)
        best_model = deepcopy(self.model)
        optimizer = optim.Adam(self.model.parameters(), lr=lr, weight_decay = weight_decay)
        scheduler = StepLR(optimizer, step_size=1, gamma=0.5)
        min_val = np.inf
        print_sys('Start Training...')
        hvg_idx = self.hvg_idx
        for epoch in range(epochs):
            self.model.train()
            for step, batch in enumerate(train_loader):
                batch.to(self.device)
                optimizer.zero_grad()
                y = batch.y
                x = batch.x
                pred = self.model(batch)
                ## autoencoder style loss with directionality enforced.
                ## Consider switching to MSE instead ?
                loss = loss_fct(pred, y, batch.pert,
                                ctrl = self.ctrl_expression,
                                dict_filter = self.dict_filter,
                                direction_lambda = self.config['direction_lambda'])
                loss.backward()
                nn.utils.clip_grad_value_(self.model.parameters(), clip_value=1.0)
                optimizer.step()
                if self.wandb:
                    self.wandb.log({'training_loss': loss.item()})
                if step % 50 == 0:
                    log = "Epoch {} Step {} Train Loss: {:.4f}"
                    print_sys(log.format(epoch + 1, step + 1, loss.item()))
            scheduler.step()
            train_run = evaluate(train_loader,self.model,False,self.device)
            val_run = evaluate(val_loader,self.model,False,self.device)
            ## computing metrics :
            try:
                train_metrics, _ = compute_metrics(train_run)
                val_metrics, _ = compute_metrics(val_run)
                log = "Epoch {}: Train Overall MSE: {:.4f} " \
                        "Validation Overall MSE: {:.4f}. "
                print_sys(log.format(epoch + 1, train_metrics['mse'],
                                    val_metrics['mse']))
                if(min_val > val_metrics["mse"]):
                    print(f"New Best model has val_mse: {val_metrics['mse']}")
                    min_val = val_metrics["mse"]
                    self.best_model = deepcopy(self.model)
            except Exception as e:
                print(f"Error while computing metrics: {e}")
            ## computing loss on the highly variable gene set.
            ## computing validation loss of the validation dataloader ?
            ## consider adding evaluation for reconstruction via the autoencoder over here

        ### TODO: Add test metrics.
        test_loader = self.dataloader['test_loader']
        print_sys("Start Testing...")
        test_res = evaluate(test_loader, self.best_model,
                            self.config['uncertainty'], self.device)
        test_metrics, test_pert_res = compute_metrics(test_res)    
        log = "Best performing model: Test Top 20 DE MSE: {:.4f}"
        print_sys(log.format(test_metrics['mse_de']))
        out = deeper_analysis(self.adata, test_res)
        out_non_dropout = non_dropout_analysis(self.adata, test_res)
        metrics = ['pearson_delta']
        # accumulate sums and counts per metric
        metric_sums = {}
        metric_counts = {}
        
        for pert, metrics in out.items():
            for metric, value in metrics.items():
                metric_sums[metric] = metric_sums.get(metric, 0) + value
                metric_counts[metric] = metric_counts.get(metric, 0) + 1

        # compute averages
        metric_avgs = {m: metric_sums[m] / metric_counts[m] for m in metric_sums}

        print(metric_avgs)



        print(f"Best Val Loss: {min_val}")
        print("Done Training ....")
        return out,out_non_dropout
    def _load_ground_truth_graphs(self, 
                                  base_path="/kaggle/input/coexpressiongraphs/Downloads/coexpression_graphs", 
                                  filename="edges.csv"):
        """
        Loads ground truth co-expression graphs from CSV files.

        This method builds a dictionary: {pert_name: 1D_weight_tensor}
        
        CRITICAL ASSUMPTIONS:
        - `self.node_map_gene`: A dict {'gene_name': gene_idx} must exist.
        - `self.model.G_coexpress`: The edge_index tensor [2, num_edges] must exist.
        - `self.node_map_pert`: A dict {'pert_name': pert_idx} must exist.
        - Files are located at: {base_path}/pert_ctrl+{pert_name}/{filename}
        """
        print("Attempting to load ground truth co-expression graphs...")
        
        # --- 1. Check for required attributes ---
        if not hasattr(self, 'node_map'):
            print("  Error: `self.node_map_gene` not found. Cannot load ground truth graphs.")
            return {}
        if not hasattr(self, 'model') or not hasattr(self.model, 'G_coexpress'):
            print("  Error: `self.model.G_coexpress` (edge_index) not found. Cannot load ground truth graphs.")
            return {}
        if not hasattr(self, 'node_map_pert'):
            print("  Error: `self.node_map_pert` not found. Cannot load ground truth graphs.")
            return {}

        # --- 2. Build Edge Index Map for fast lookup ---
        # This maps (u_idx, v_idx) -> position in the edge_weight tensor
        try:
            edge_index = self.model.G_coexpress.cpu()
            num_edges = edge_index.shape[1]
            edge_index_map = {}
            for i in range(num_edges):
                u_idx = edge_index[0, i].item()
                v_idx = edge_index[1, i].item()
                edge_index_map[(u_idx, v_idx)] = i
            
            gene_name_to_idx = self.node_map_gene
            print(f"  Built edge index map for {num_edges} edges.")
        except Exception as e:
            print(f"  Error building edge_index_map: {e}. Aborting GT load.")
            return {}

        # --- 3. Get all perturbation names, including 'ctrl' ---
        # (Based on the logic in your original function)
        pert_names = list(self.node_map_pert.keys())
        if 'ctrl' not in pert_names:
            pert_names.append('ctrl')

        gt_graph_store = {}
        
        # --- 4. Iterate and load each GT graph file ---
        for pert_name in pert_names:
            # Format: coexpression_graphs/pert_ctrl+GATA1/edges.csv
            file_path = os.path.join(base_path, f"pert_{pert_name}", filename)
            
            if not os.path.exists(file_path):
                print(f"  Info: No GT graph file found for '{pert_name}' at {file_path}. Skipping.")
                continue

            try:
                # Initialize a zero-vector for this GT graph's weights
                gt_weights_tensor = torch.zeros(num_edges, device=self.device)
                
                with open(file_path, 'r', encoding='utf-8') as f:
                    reader = csv.reader(f)
                    header = next(reader) # Skip header
                    
                    edges_found = 0
                    edges_not_in_index = 0
                    
                    for row in reader:
                        if len(row) < 3: continue # Skip malformed rows
                        source_name, target_name, weight_str = row[0], row[1], row[2]
                        
                        u_idx = gene_name_to_idx.get(source_name)
                        v_idx = gene_name_to_idx.get(target_name)
                        
                        if u_idx is None or v_idx is None:
                            continue # Gene name not in our map
                        
                        try:
                            weight = float(weight_str)
                        except ValueError:
                            continue # Invalid weight
                        
                        # Check for the edge in our model's edge_index
                        edge_pos = edge_index_map.get((u_idx, v_idx))
                        
                        if edge_pos is not None:
                            gt_weights_tensor[edge_pos] = weight
                            edges_found += 1
                        else:
                            # Optional: Check for reverse edge if graph is undirected
                            edge_pos_rev = edge_index_map.get((v_idx, u_idx))
                            if edge_pos_rev is not None:
                                gt_weights_tensor[edge_pos_rev] = weight
                                edges_found += 1
                            else:
                                edges_not_in_index += 1
                
                gt_graph_store[pert_name] = gt_weights_tensor.detach()
                print(f"  Loaded GT graph for '{pert_name}'. "
                      f"Mapped {edges_found} edges. ({edges_not_in_index} edges from file were not in model's G_coexpress).")

            except Exception as e:
                print(f"  Error loading GT graph for '{pert_name}' from {file_path}: {e}")

        print(f"Successfully loaded {len(gt_graph_store)} ground truth graphs.")
        return gt_graph_store

    # --- NEW HELPER METHOD 2: Pearson Correlation ---
    
    def calculate_pearson(self, x, y):
        """Calculates the Pearson correlation coefficient between two 1D tensors."""
        # Center the vectors
        x_centered = x - torch.mean(x)
        y_centered = y - torch.mean(y)
        
        # Use cosine similarity on centered vectors
        # Add epsilon for numerical stability in case of zero variance
        epsilon = 1e-8
        cos_sim = F.cosine_similarity(x_centered.unsqueeze(0), 
                                      y_centered.unsqueeze(0), 
                                      eps=epsilon)
        return cos_sim.item()

    # --- UPDATED Main Function ---
    
    def look_cell_graphs(self, dataloader):
        """
        Analyzes and compares predicted graph edge weights for different
        perturbations against:
        1. The baseline control graph.
        2. The corresponding ground truth co-expression graph.
        
        Assumes:
        - self.model.G_coexpress_weight: The baseline control edge weights (1D Tensor).
        - self.model.compute_graphs() returns: (pred, {"graphs": [Data, Data, ...]}).
        - The input `batch.pert` corresponds 1-to-1 with the list of output graphs.
        - `self.node_map_gene` exists for loading GT graphs.
        """
        
        print("Starting graph comparison analysis...")
        
        # --- 1. Get Baseline Control Graph ---
        try:
            control_weights = self.model.G_coexpress_weight.to(self.device).detach()
            num_edges = control_weights.shape[0]
            
            if self.model.G_coexpress_weight.shape[0] != self.model.G_coexpress.shape[1]:
                 print(f"Warning: Control weights shape ({control_weights.shape[0]}) "
                       f"does not match edge_index shape ({self.model.G_coexpress.shape[1]}).")

            print(f"Loaded baseline control graph with {num_edges} edges.")
            
        except AttributeError:
            print("Error: `self.model.G_coexpress_weight` or `self.model.G_coexpress` not found. Aborting.")
            return
        
        # --- 1.5. [NEW] Load Ground Truth Graphs ---
        # This calls the new helper method and stores GT graphs in a dictionary
        # self.gt_graph_store = { 'pert_name_1': tensor, 'pert_name_2': tensor, ... }
        try:
            # This assumes _load_ground_truth_graphs is a method of the same class
            self.gt_graph_store = self._load_ground_truth_graphs() 
        except Exception as e:
            print(f"Error during Ground Truth graph loading: {e}. Proceeding without GT comparison.")
            self.gt_graph_store = {} # Ensure it's a dict
        
        # --- 2. Create Perturbation Name Map ---
        try:
            idx_to_pert_name = {v: k for k, v in self.node_map_pert.items()}
            idx_to_pert_name[-1] = 'ctrl'
        except AttributeError:
            print("Error: `self.node_map_pert` not found. Aborting.")
            return

        # Dictionary to store aggregated results
        results_store = {}

        # --- 3. Iterate Through Dataloader ---
        for step, batch in enumerate(dataloader):
            with torch.no_grad():
                batch.to(self.device)
                
                # Run the model
                pred, graph_data = self.model.compute_graphs(batch)

                # --- 4. Get Predicted Graphs and Labels ---
                predicted_graphs_list = graph_data.get("graphs")
                if predicted_graphs_list is None or not isinstance(predicted_graphs_list, list):
                    print(f"Error: 'graphs' key not in model output or is not a list. Aborting batch {step}.")
                    continue
                
                num_graphs_in_batch = len(predicted_graphs_list)
                pert_indices = np.array(batch.pert) 

                if num_graphs_in_batch != pert_indices.shape[0]:
                    print(f"Warning: Mismatch in batch {step}. "
                          f"Model output {num_graphs_in_batch} graphs, but input batch had {pert_indices.shape[0]} labels. Skipping.")
                    continue

                # --- 5. Compare Each Graph in Batch ---
                for i in range(num_graphs_in_batch):
                    
                    pert_idx = pert_indices[i].item()
                    pert_name = idx_to_pert_name.get(pert_idx, f"Unknown_idx_{pert_idx}")
                    
                    data_graph_i = predicted_graphs_list[i]
                    predicted_weights_graph_i = data_graph_i.edge_weight.detach()
                    
                    if predicted_weights_graph_i.shape[0] != num_edges:
                        print(f"Warning: Shape mismatch in batch {step}, graph {i} (pert: {pert_name}). "
                              f"Expected {num_edges} edges, but predicted graph has {predicted_weights_graph_i.shape[0]}. Skipping graph.")
                        continue
                    
                    # --- 5a. Comparison vs. Control (Original Logic) ---
                    
                    edge_diff = predicted_weights_graph_i - control_weights
                    mean_abs_diff = torch.mean(torch.abs(edge_diff)).item()
                    
                    epsilon = 1e-6
                    control_is_zero = torch.abs(control_weights) < epsilon
                    pred_is_zero = torch.abs(predicted_weights_graph_i) < epsilon
                    
                    new_edges_mask = control_is_zero & (~pred_is_zero)
                    num_new_edges = torch.sum(new_edges_mask).item()
                    
                    avg_new_edge_strength = 0.0
                    if num_new_edges > 0:
                        avg_new_edge_strength = torch.mean(torch.abs(predicted_weights_graph_i[new_edges_mask])).item()

                    lost_edges_mask = (~control_is_zero) & pred_is_zero
                    num_lost_edges = torch.sum(lost_edges_mask).item()

                    # --- 5b. [NEW] Comparison vs. Ground Truth ---
                    
                    # Get the pre-loaded GT graph tensor for this perturbation
                    gt_weights = self.gt_graph_store.get(pert_name)
                    
                    gt_pearson_corr = np.nan
                    gt_cos_sim = np.nan
                    
                    if gt_weights is not None:
                        # Check for shape mismatch (should not happen if loading was correct)
                        if gt_weights.shape[0] == num_edges:
                            # Use new helper function for Pearson
                            gt_pearson_corr = self.calculate_pearson(predicted_weights_graph_i, gt_weights)
                            
                            # Calculate Cosine Similarity
                            gt_cos_sim = F.cosine_similarity(
                                predicted_weights_graph_i.unsqueeze(0), 
                                gt_weights.unsqueeze(0)
                            ).item()
                        else:
                            print(f"Warning: GT graph for {pert_name} has shape {gt_weights.shape[0]} but expected {num_edges}. Skipping GT comparison.")
                    # else: No GT graph was loaded for this pert_name, metrics will remain np.nan

                    # --- 6. Store Results (Updated) ---
                    if pert_name not in results_store:
                        results_store[pert_name] = {
                            'count': 0,
                            'mean_abs_diff': [],
                            'num_new_edges': [],
                            'avg_new_edge_strength': [],
                            'num_lost_edges': [],
                            'gt_pearson_corr': [],  # New
                            'gt_cos_sim': []        # New
                        }
                    
                    results_store[pert_name]['count'] += 1
                    results_store[pert_name]['mean_abs_diff'].append(mean_abs_diff)
                    results_store[pert_name]['num_new_edges'].append(num_new_edges)
                    if num_new_edges > 0:
                        results_store[pert_name]['avg_new_edge_strength'].append(avg_new_edge_strength)
                    results_store[pert_name]['num_lost_edges'].append(num_lost_edges)
                    
                    # Append GT metrics (will append np.nan if not found)
                    results_store[pert_name]['gt_pearson_corr'].append(gt_pearson_corr)
                    results_store[pert_name]['gt_cos_sim'].append(gt_cos_sim)

        # --- 7. Print Final Aggregated Report (Updated) ---
        print("\n--- 📊 Graph Comparison Report ---")
        print(f"Analyzed {sum(v['count'] for v in results_store.values())} total graphs across {len(results_store)} perturbations.")
        
        for pert_name in sorted(results_store.keys(), key=lambda x: (x == 'ctrl', x)): # Sort, put 'ctrl' first
            stats = results_store[pert_name]
            count = stats['count']
            
            # --- Original Averages ---
            avg_mean_diff = np.mean(stats['mean_abs_diff'])
            avg_new_edges = np.mean(stats['num_new_edges'])
            avg_lost_edges = np.mean(stats['num_lost_edges'])
            
            if stats['avg_new_edge_strength']:
                avg_new_edge_strength = np.mean(stats['avg_new_edge_strength'])
            else:
                avg_new_edge_strength = 0.0

            # --- [NEW] GT Averages ---
            # Use np.nanmean to safely ignore 'nan' values if a GT graph was missing
            avg_gt_pearson = np.nanmean(stats['gt_pearson_corr'])
            avg_gt_cos_sim = np.nanmean(stats['gt_cos_sim'])

            print(f"\n**Perturbation: {pert_name} (n={count})**")
            print(f"  --- vs. Control Graph ---")
            print(f"    Avg. Mean Absolute Edge Diff: {avg_mean_diff:.5f}")
            print(f"    Avg. New Edges Created (0 -> non-0): {avg_new_edges:.2f}")
            print(f"    Avg. Strength of New Edges: {avg_new_edge_strength:.5f}")
            print(f"    Avg. Edges Lost (non-0 -> 0): {avg_lost_edges:.2f}")
            
            print(f"  --- vs. Ground Truth Graph ---")
            # Only print GT stats if they are not all 'nan'
            if not np.isnan(avg_gt_pearson):
                print(f"    Avg. Pearson Correlation: {avg_gt_pearson:.4f}")
                print(f"    Avg. Cosine Similarity: {avg_gt_cos_sim:.4f}")
            else:
                print(f"    (No Ground Truth graph loaded for this perturbation)")

        print("-----------------------------------")
        
        return results_store
    def get_perturbation_graphs(self,
                                dataloader,
                                base_path="/kaggle/input/coexpressiongraphs/Downloads/coexpression_graphs",
                                filename="edges.csv"):
        
        pert_names = list(self.node_map_pert.keys())
        if 'ctrl' not in pert_names:
            pert_names.append('ctrl')

        gt_graph_store = {}
        
        # --- 3. Iterate and load each GT graph file ---
        graphs = {}
        for pert_name in pert_names:
            file_path = os.path.join(base_path, f"pert_{pert_name}+ctrl", filename)
            ## its in source,target form, so loading the entire graph using networkX
            if not os.path.exists(file_path):
                print(f"  Info: No GT graph file found for '{pert_name}' at {file_path}. Skipping.")
                continue
            # Source - https://stackoverflow.com/a
            # Posted by ducminh, modified by community. See post 'Timeline' for change history
            # Retrieved 2025-11-13, License - CC BY-SA 3.0

            Data = open(file_path, "r")
            next(Data, None)  # skip the first line in the input file
            Graphtype = nx.Graph()
            G = nx.parse_edgelist(Data, delimiter=',', create_using=Graphtype,
                                nodetype=int, data=(('weight', float),))
            ## computing graph metrics wrt the control graph 
            graphs[pert_name] = G ##
            
            ## remapping via node_map_gene
            mapped_G = nx.relabel_nodes(G, self.node_map_gene)

# %%
# !mkdir -p data
# !mkdir model_output

# %%
import scanpy as sc
from gears.utils import zip_data_download_wrapper
def data_download(data_name,data_dir,extract_dir):
    if data_name == 'norman':
        url = 'https://dataverse.harvard.edu/api/access/datafile/6154020'
    elif data_name == 'adamson':
        url = 'https://dataverse.harvard.edu/api/access/datafile/6154417'
    elif data_name == 'dixit':
        url = 'https://dataverse.harvard.edu/api/access/datafile/6154416'
    elif data_name == 'replogle_k562_essential':
        ## Note: This is not the complete dataset and has been filtered
        url = 'https://dataverse.harvard.edu/api/access/datafile/7458695'
    elif data_name == 'replogle_rpe1_essential':
        ## Note: This is not the complete dataset and has been filtered
        url = 'https://dataverse.harvard.edu/api/access/datafile/7458694'
    else:
        print("None of these datasets exist")
        return
    zip_data_download_wrapper(url, data_dir, extract_dir)


DATA_ROOT="data"
DATASET_NAME="norman"
FNAME=os.path.join(DATA_ROOT,DATASET_NAME,"perturb_processed.h5ad")
# CTRL_NAME="ctrl"

# %%
# data_download(data_name= DATASET_NAME, data_dir= os.path.join(DATA_ROOT,DATASET_NAME),extract_dir = DATA_ROOT)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ctrl_dir = os.path.join(DATA_ROOT,"ctrl" + DATASET_NAME)
# adata = sc.read_h5ad(FNAME)
# ctrl_adata = adata[adata.obs['condition']==CTRL_NAME]
# os.makedirs(ctrl_dir ,exist_ok=True)
# ctrl_adata.write_h5ad(filename=os.path.join(ctrl_dir, "perturb_processed.h5ad"))

# ## creating symlinks to all other files in DATA_ROOT/DATASET_NAME/ to ctrl_dir, with excpetion of perturb_processed.h5ad
# for f in os.listdir(os.path.join(DATA_ROOT,DATASET_NAME)):
#     if f!="perturb_processed.h5ad":
#         if not os.path.exists(os.path.join(ctrl_dir,f)):
#             os.symlink(os.path.abspath(os.path.join(DATA_ROOT,DATASET_NAME,f)), os.path.join(ctrl_dir,f))

# %%
pert_data = PertData_(data_path=DATA_ROOT)
pert_data.load(data_name = DATASET_NAME,data_path = os.path.join(DATA_ROOT,DATASET_NAME))
pert_data.prepare_split(split = 'single', seed = 1,combo_single_split_test_set_fraction=0.3)
pert_data.get_dataloader(batch_size=32,test_batch_size=128)
# Out:
# Downloading...
# 100%|██████████| 9.46M/9.46M [00:00<00:00, 50.2MiB/s]
# Downloading...
# norman
# 100%|██████████| 169M/169M [00:06<00:00, 25.1MiB/s]
# Extracting zip file...
# Done!
# Downloading...
# 100%|██████████| 559k/559k [00:00<00:00, 7.30MiB/s]
# These perturbations are not in the GO graph and their perturbation can thus not be predicted
# ['RHOXF2BB+ctrl' 'LYL1+IER5L' 'ctrl+IER5L' 'KIAA1804+ctrl' 'IER5L+ctrl'
#  'RHOXF2BB+ZBTB25' 'RHOXF2BB+SET']
# Creating pyg object for each cell in the data...
# Creating dataset file...
# 100%|██████████| 277/277 [05:06<00:00,  1.11s/it]
# Done!
# Saving new dataset pyg object at data/norman/data_pyg/cell_graphs.pkl
# Done!
# Creating new splits....
# Saving new splits at data/norman/splits/norman_single_1_0.75.pkl
# Done!
# Creating dataloaders....
# Done!
# {'test': ['TSC22D1+ctrl', 'MAML2+ctrl', 'DUSP9+ctrl', 'BCORL1+ctrl', 'MEIS1+ctrl', 'CBL+ctrl', 'ctrl+SET', 'SLC4A1+ctrl', 'ZNF318+ctrl', 'COL2A1+ctrl', 'MAP4K5+ctrl', 'UBASH3B+ctrl', 'AHR+ctrl', 'S1PR2+ctrl', 'ctrl+CNN1', 'CELF2+ctrl', 'MAP4K3+ctrl', 'CDKN1A+ctrl', 'ctrl+MEIS1', 'MAPK1+ctrl', 'C19orf26+ctrl', 'ctrl+UBASH3B', 'CKS1B+ctrl', 'PRTG+ctrl', 'BPGM+ctrl', 'C3orf72+ctrl', 'FOXL2+ctrl', 'CNN1+ctrl', 'ctrl+CDKN1A', 'ctrl+C19orf26', 'ARID1A+ctrl', 'ctrl+COL2A1', 'BCL2L11+ctrl', 'OSR2+ctrl', 'SET+ctrl', 'ctrl+SPI1', 'ctrl+STIL', 'CEBPB+ctrl', 'ctrl+PRTG', 'CDKN1B+ctrl', 'JUN+ctrl', 'PTPN13+ctrl', 'ctrl+MAPK1', 'PTPN9+ctrl', 'ctrl+SNAI1', 'ctrl+CEBPB', 'PRDM1+ctrl', 'ctrl+PTPN9', 'ctrl+OSR2', 'ctrl+FOXL2', 'SPI1+ctrl', 'SNAI1+ctrl', 'EGR1+ctrl', 'STIL+ctrl', 'CDKN1C+ctrl', 'ctrl+CDKN1B'], 'train': ['KLF1+MAP2K6', 'ctrl', 'CEBPE+RUNX1T1', 'ctrl+CEBPE', 'TGFBR2+ETS2', 'SGK1+TBX3', 'ctrl+ELMSAN1', 'ctrl+FOXA1', 'FOXA3+FOXA1', 'ETS2+IGDCC3', 'GLB1L2+ctrl', 'KLF1+ctrl', 'MAP2K6+IKZF3', 'BAK1+ctrl', 'FEV+ctrl', 'ctrl+ETS2', 'ctrl+FEV', 'TBX3+ctrl', 'LHX1+ctrl', 'KLF1+FOXA1', 'TBX3+TBX2', 'ctrl+KLF1', 'ctrl+ZBTB25', 'CEBPE+KLF1', 'SLC6A9+ctrl', 'MIDN+ctrl', 'DLX2+ctrl', 'HES7+ctrl', 'IGDCC3+ZBTB25', 'FOXO4+ctrl', 'KLF1+BAK1', 'ctrl+RUNX1T1', 'POU3F2+ctrl', 'MAP2K3+ctrl', 'ZBTB25+ctrl', 'ZC3HAV1+CEBPE', 'MAP2K3+MAP2K6', 'PTPN1+ctrl', 'ctrl+TBX2', 'RUNX1T1+ctrl', 'PTPN12+ctrl', 'ctrl+MAP7D1', 'MAP2K3+IKZF3', 'FOSB+ctrl', 'IRF1+ctrl', 'TMSB4X+BAK1', 'IKZF3+ctrl', 'ETS2+CEBPE', 'HOXB9+ctrl', 'ctrl+HOXC13', 'LHX1+ELMSAN1', 'ctrl+HOXB9', 'ETS2+ctrl', 'FOXA3+ctrl', 'CEBPE+ctrl', 'KIF18B+KIF2C', 'ctrl+SAMD1', 'COL1A1+ctrl', 'PTPN12+UBASH3A', 'FOXF1+ctrl', 'ZBTB1+ctrl', 'FEV+MAP7D1', 'PLK4+ctrl', 'ARRDC3+ctrl', 'LYL1+ctrl', 'ctrl+MAP2K6', 'SGK1+ctrl', 'ctrl+DLX2', 'MAP2K6+ctrl', 'ctrl+TBX3', 'FOSB+CEBPE', 'ctrl+CEBPA', 'HNF4A+ctrl', 'MAP7D1+ctrl', 'KMT2A+ctrl', 'MAP2K6+ELMSAN1', 'IGDCC3+ctrl', 'KLF1+CEBPA', 'TGFBR2+IGDCC3', 'SAMD1+ZBTB1', 'TMSB4X+ctrl', 'FOXA3+HOXB9', 'KIF2C+ctrl', 'ctrl+ZBTB1', 'ctrl+KIF2C', 'MAP2K3+ELMSAN1', 'CSRNP1+ctrl', 'CEBPE+CEBPA', 'ctrl+UBASH3A', 'NCL+ctrl', 'ctrl+BAK1', 'ZC3HAV1+HOXC13', 'ctrl+IKZF3', 'ZBTB10+PTPN12', 'FOXF1+HOXB9', 'ZC3HAV1+ctrl', 'HOXC13+ctrl', 'TBX2+ctrl', 'ATL1+ctrl', 'CEBPE+PTPN12', 'CEBPA+ctrl', 'TGFBR2+ctrl', 'FOXA1+HOXB9', 'SAMD1+TGFBR2', 'ZBTB10+ctrl', 'FOXA1+ctrl', 'SAMD1+ctrl', 'ELMSAN1+ctrl', 'SGK1+TBX2', 'ETS2+MAP7D1', 'UBASH3A+ctrl', 'KLF1+TGFBR2', 'ETS2+IKZF3', 'PTPN12+ZBTB25', 'HOXA13+ctrl', 'ctrl+FOXF1', 'FOSB+IKZF3', 'FOSB+PTPN12', 'ctrl+PTPN12', 'SAMD1+PTPN12', 'HK2+ctrl', 'ctrl+IGDCC3', 'ZBTB10+ELMSAN1', 'ctrl+TGFBR2', 'FOXA3+FOXF1', 'ZC3HAV1+CEBPA', 'KIF18B+ctrl', 'ZBTB10+DLX2', 'FOXA1+FOXF1'], 'val': ['RREB1+ctrl', 'CBFA2T3+ctrl', 'ctrl+CBFA2T3', 'TP73+ctrl', 'CLDN6+ctrl', 'ISL2+ctrl', 'ctrl+CLDN6', 'CNNM4+ctrl', 'NIT1+ctrl', 'ctrl+ISL2', 'ctrl+SLC38A2', 'CITED1+ctrl']}

# %%
# ctrl_pertdata = PertData_(data_path=DATA_ROOT)
# ctrl_pertdata.load(data_name=f"ctrl{DATASET_NAME}",data_path = os.path.join(DATA_ROOT,f"ctrl{DATASET_NAME}"))
# ctrl_pertdata.prepare_split(split = 'single', seed = 1,combo_single_split_test_set_fraction=0.3,val_size=0.3)
# ctrl_pertdata.get_dataloader(batch_size = 32, test_batch_size = 128)

# %%
OUTPUT_PATH = "model_output"
# gears_mech  = GEARS_PRETRAIN(pert_data=ctrl_pertdata, device='cuda', weight_bias_track=False, proj_name='GEARS', exp_name='GEARS')
gears_mech  = GEARS_PRETRAIN(pert_data=pert_data, device='cuda', weight_bias_track=False, proj_name='GEARS', exp_name='GEARS')

gears_mech.model_initialize(
    hidden_size=64, num_go_gnn_layers=1,
    num_gene_gnn_layers=1, decoder_hidden_size=16,
    num_similar_genes_go_graph=20, num_similar_genes_co_express_graph=20,
    coexpress_threshold=0.4, uncertainty=False, uncertainty_reg=1,
    direction_lambda=0.1, G_go=None, G_go_weight=None,
    G_coexpress=None, G_coexpress_weight=None, no_perturb=False,
    gears_model=True, model_no=1,
    num_hops=3,num_add=6)
# Out:
# Graph modification in progress. Original edge count: 6359
# Processing nodes:   0%|          | 0/13374 [00:00<?, ?it/s]
# Downloading...
# Added 1443 new zero-weight edges.
# Tensors updated. New edge count: 7802
# 100%|██████████| 60.7M/60.7M [00:02<00:00, 23.2MiB/s]
# Extracting tar file...
# Done!
# Downprojected Rank 1560
# Expected Dimensions of activations through encoder: [64, 128, 128]

# %%
# gears_mech.pretrain_ctrl(epochs=20, lr=1e-3, weight_decay=5e-4)
# In your training script, before calling gears_mech.train()
torch.autograd.set_detect_anomaly(True)

# gears_mech.pretrain_ctrl(epochs=20, lr=1e-3, weight_decay=5e-4)
deeperanalysis,nondropoutanalysis = gears_mech.train(epochs=4,lr=1e-3,weight_decay=5e-4)
gears_mech.save_model(OUTPUT_PATH)
## writing out control_adata expression
# Out:
# Start Training...
# Training Phase with perturbing graph .....
# Length of train_loader: 1503
# Length of val_loader 96
# Epoch 1 Step 1 Train Loss: 0.4481
# Epoch 1 Step 51 Train Loss: 0.3767
# Epoch 1 Step 101 Train Loss: 0.4259
# Epoch 1 Step 151 Train Loss: 0.3253
# Epoch 1 Step 201 Train Loss: 0.3675
# Epoch 1 Step 251 Train Loss: 0.3565
# Epoch 1 Step 301 Train Loss: 0.3559
# Epoch 1 Step 351 Train Loss: 0.3330
# Epoch 1 Step 401 Train Loss: 0.4105
# Epoch 1 Step 451 Train Loss: 0.3564
# Epoch 1 Step 501 Train Loss: 0.3487
# Epoch 1 Step 551 Train Loss: 0.3756
# Epoch 1 Step 601 Train Loss: 0.3479
# Epoch 1 Step 651 Train Loss: 0.4100
# Epoch 1 Step 701 Train Loss: 0.3488
# Epoch 1 Step 751 Train Loss: 0.3397
# Epoch 1 Step 801 Train Loss: 0.3416
# Epoch 1 Step 851 Train Loss: 0.3317
# Epoch 1 Step 901 Train Loss: 0.3468
# Epoch 1 Step 951 Train Loss: 0.3075
# Epoch 1 Step 1001 Train Loss: 0.4766
# Epoch 1 Step 1051 Train Loss: 0.3547
# Epoch 1 Step 1101 Train Loss: 0.3050
# Epoch 1 Step 1151 Train Loss: 0.3551
# Epoch 1 Step 1201 Train Loss: 0.3790
# Epoch 1 Step 1251 Train Loss: 0.3393
# Epoch 1 Step 1301 Train Loss: 0.3508
# Epoch 1 Step 1351 Train Loss: 0.3330
# Epoch 1 Step 1401 Train Loss: 0.3804
# Epoch 1 Step 1451 Train Loss: 0.3567
# Epoch 1 Step 1501 Train Loss: 0.4226
# Epoch 1: Train Overall MSE: 0.0070 Validation Overall MSE: 0.0076.
# New Best model has val_mse: 0.00756050122436136
# Epoch 2 Step 1 Train Loss: 0.3487
# Epoch 2 Step 51 Train Loss: 0.3890
# Epoch 2 Step 101 Train Loss: 0.3754
# Epoch 2 Step 151 Train Loss: 0.3961
# Epoch 2 Step 201 Train Loss: 0.3845
# Epoch 2 Step 251 Train Loss: 0.3857
# Epoch 2 Step 301 Train Loss: 0.3899
# Epoch 2 Step 351 Train Loss: 0.3546
# Epoch 2 Step 401 Train Loss: 0.3750
# Epoch 2 Step 451 Train Loss: 0.3932
# Epoch 2 Step 501 Train Loss: 0.4052
# Epoch 2 Step 551 Train Loss: 0.3643
# Epoch 2 Step 601 Train Loss: 0.4107
# Epoch 2 Step 651 Train Loss: 0.3731
# Epoch 2 Step 701 Train Loss: 0.4044
# Epoch 2 Step 751 Train Loss: 0.3690
# Epoch 2 Step 801 Train Loss: 0.3809
# Epoch 2 Step 851 Train Loss: 0.3631
# Epoch 2 Step 901 Train Loss: 0.4035
# Epoch 2 Step 951 Train Loss: 0.3779
# Epoch 2 Step 1001 Train Loss: 0.3664
# Epoch 2 Step 1051 Train Loss: 0.4235
# Epoch 2 Step 1101 Train Loss: 0.3840
# Epoch 2 Step 1151 Train Loss: 0.4133
# Epoch 2 Step 1201 Train Loss: 0.3923
# Epoch 2 Step 1251 Train Loss: 0.4096
# Epoch 2 Step 1301 Train Loss: 0.3923
# Epoch 2 Step 1351 Train Loss: 0.3982
# Epoch 2 Step 1401 Train Loss: 0.4128
# Epoch 2 Step 1451 Train Loss: 0.3977
# Epoch 2 Step 1501 Train Loss: 0.3773
# Epoch 2: Train Overall MSE: 0.0064 Validation Overall MSE: 0.0054.
# New Best model has val_mse: 0.005421226320322603
# Epoch 3 Step 1 Train Loss: 0.4006
# Epoch 3 Step 51 Train Loss: 0.3785
# Epoch 3 Step 101 Train Loss: 0.3804
# Epoch 3 Step 151 Train Loss: 0.3550
# Epoch 3 Step 201 Train Loss: 0.3904
# Epoch 3 Step 251 Train Loss: 0.3693
# Epoch 3 Step 301 Train Loss: 0.4234
# Epoch 3 Step 351 Train Loss: 0.3711
# Epoch 3 Step 401 Train Loss: 0.4478
# Epoch 3 Step 451 Train Loss: 0.4009
# Epoch 3 Step 501 Train Loss: 0.3780
# Epoch 3 Step 551 Train Loss: 0.3941
# Epoch 3 Step 601 Train Loss: 0.3714
# Epoch 3 Step 651 Train Loss: 0.4036
# Epoch 3 Step 701 Train Loss: 0.3852
# Epoch 3 Step 751 Train Loss: 0.3776
# Epoch 3 Step 801 Train Loss: 0.3859
# Epoch 3 Step 851 Train Loss: 0.3889
# Epoch 3 Step 901 Train Loss: 0.3794
# Epoch 3 Step 951 Train Loss: 0.4275
# Epoch 3 Step 1001 Train Loss: 0.4553
# Epoch 3 Step 1051 Train Loss: 0.4207
# Epoch 3 Step 1101 Train Loss: 0.4035
# Epoch 3 Step 1151 Train Loss: 0.3636
# Epoch 3 Step 1201 Train Loss: 0.3914
# Epoch 3 Step 1251 Train Loss: 0.4157
# Epoch 3 Step 1301 Train Loss: 0.3624
# Epoch 3 Step 1351 Train Loss: 0.4202
# Epoch 3 Step 1401 Train Loss: 0.4114
# Epoch 3 Step 1451 Train Loss: 0.4170
# Epoch 3 Step 1501 Train Loss: 0.3673
# Epoch 3: Train Overall MSE: 0.0075 Validation Overall MSE: 0.0073.
# Epoch 4 Step 1 Train Loss: 0.4149
# Epoch 4 Step 51 Train Loss: 0.3883
# Epoch 4 Step 101 Train Loss: 0.3799
# Epoch 4 Step 151 Train Loss: 0.3959
# Epoch 4 Step 201 Train Loss: 0.3723
# Epoch 4 Step 251 Train Loss: 0.4020
# Epoch 4 Step 301 Train Loss: 0.4201
# Epoch 4 Step 351 Train Loss: 0.3797
# Epoch 4 Step 401 Train Loss: 0.4123
# Epoch 4 Step 451 Train Loss: 0.3968
# Epoch 4 Step 501 Train Loss: 0.4082
# Epoch 4 Step 551 Train Loss: 0.4422
# Epoch 4 Step 601 Train Loss: 0.4153
# Epoch 4 Step 651 Train Loss: 0.4001
# Epoch 4 Step 701 Train Loss: 0.4070
# Epoch 4 Step 751 Train Loss: 0.4100
# Epoch 4 Step 801 Train Loss: 0.3610
# Epoch 4 Step 851 Train Loss: 0.3901
# Epoch 4 Step 901 Train Loss: 0.4400
# Epoch 4 Step 951 Train Loss: 0.4268
# Epoch 4 Step 1001 Train Loss: 0.3698
# Epoch 4 Step 1051 Train Loss: 0.3937
# Epoch 4 Step 1101 Train Loss: 0.4425
# Epoch 4 Step 1151 Train Loss: 0.3906
# Epoch 4 Step 1201 Train Loss: 0.3904
# Epoch 4 Step 1251 Train Loss: 0.4027
# Epoch 4 Step 1301 Train Loss: 0.3840
# Epoch 4 Step 1351 Train Loss: 0.4424
# Epoch 4 Step 1401 Train Loss: 0.3807
# Epoch 4 Step 1451 Train Loss: 0.4037
# Epoch 4 Step 1501 Train Loss: 0.4264
# Epoch 4: Train Overall MSE: 0.0079 Validation Overall MSE: 0.0091.
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.2174
# {'frac_correct_direction_all': 0.3995221577233471, 'frac_correct_direction_20': 0.5553571428571428, 'frac_correct_direction_50': 0.5107142857142858, 'frac_correct_direction_100': 0.4646428571428573, 'frac_correct_direction_200': 0.4244642857142857, 'frac_correct_direction_20_nonzero': 0.8902630959214372, 'frac_in_range': 0.9930555555555556, 'frac_in_range_45_55': 0.06343949795738912, 'frac_in_range_40_60': 0.14128877583941285, 'frac_in_range_25_75': 0.4900836650449652, 'mean_sigma': 0.8522990563741097, 'std_sigma': 0.5413409233666383, 'frac_sigma_below_1': 0.7603603127641588, 'frac_sigma_below_2': 0.9703152347308694, 'pearson_delta': 0.2481822885040726, 'pearson_delta_de': 0.395775732351467, 'fold_change_gap_all': 0.44286121654191185, 'fold_change_gap_upreg_3': 22.213992745377297, 'fold_change_gap_upreg_10': 124.58509410511364, 'pearson_delta_top200_hvg': 0.38220914652837173, 'pearson_top200_hvg': 0.9725839793682098, 'mse_top200_hvg': 0.05040086649491319, 'pearson_delta_top20_de': 0.395775732351467, 'pearson_top20_de': 0.8314205434705529, 'mse_top20_de': 0.21735699839856742, 'pearson_delta_top200_de': 0.4364721351968391, 'pearson_top200_de': 0.9767928879175868, 'mse_top200_de': 0.04657150140181849, 'pearson_delta_top100_de': 0.4332860954371946, 'pearson_top100_de': 0.9610876792243549, 'mse_top100_de': 0.07626317638122211, 'pearson_delta_top50_de': 0.4405142767354846, 'pearson_top50_de': 0.9153614597661155, 'mse_top50_de': 0.12184242054146514}
# Best Val Loss: 0.005421226320322603
# Done Training ....

# %%
results_store = gears_mech.look_cell_graphs(dataloader=gears_mech.dataloader["train_loader"])
# Out:
# Starting graph comparison analysis...
# Loaded baseline control graph with 7802 edges.
# Attempting to load ground truth co-expression graphs...
#   Error: `self.node_map_gene` not found. Cannot load ground truth graphs.
#
# --- 📊 Graph Comparison Report ---
# Analyzed 48096 total graphs across 129 perturbations.
#
# **Perturbation: Unknown_idx_ARRDC3+ctrl (n=405)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.94848
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.65485
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ATL1+ctrl (n=305)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.63620
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.30654
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_BAK1+ctrl (n=534)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.07860
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.78468
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_CEBPA+ctrl (n=322)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.34225
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 0.88551
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_CEBPE+CEBPA (n=240)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.32501
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 0.81494
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_CEBPE+KLF1 (n=389)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48953
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.11866
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_CEBPE+PTPN12 (n=317)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48184
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10732
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_CEBPE+RUNX1T1 (n=1030)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.46626
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.08406
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_CEBPE+ctrl (n=473)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.44962
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.05870
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_COL1A1+ctrl (n=257)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47771
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10118
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_CSRNP1+ctrl (n=354)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.03447
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.74064
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_DLX2+ctrl (n=316)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47743
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10077
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ELMSAN1+ctrl (n=353)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.93352
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.63993
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ETS2+CEBPE (n=320)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.45445
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.06610
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ETS2+IGDCC3 (n=365)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.77234
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.47143
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ETS2+IKZF3 (n=388)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22700
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ETS2+MAP7D1 (n=265)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.04268
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.74883
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ETS2+ctrl (n=375)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.23260
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.93836
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FEV+MAP7D1 (n=246)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.56985
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22652
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FEV+ctrl (n=173)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.64903
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.32203
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOSB+CEBPE (n=142)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.41152
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 0.99865
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOSB+IKZF3 (n=204)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22701
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOSB+PTPN12 (n=291)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.49463
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.12617
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOSB+ctrl (n=502)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.46661
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.08458
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXA1+FOXF1 (n=237)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48113
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10627
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXA1+HOXB9 (n=266)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.46960
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.08907
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXA1+ctrl (n=426)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.49299
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.12371
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXA3+FOXA1 (n=181)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47390
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.09550
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXA3+FOXF1 (n=146)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48000
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10460
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXA3+HOXB9 (n=301)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.46862
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.08760
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXA3+ctrl (n=409)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.49143
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.12143
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXF1+HOXB9 (n=173)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47546
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.09784
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXF1+ctrl (n=448)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.04959
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.75573
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_FOXO4+ctrl (n=189)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48598
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.11344
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_GLB1L2+ctrl (n=378)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.89918
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.60569
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_HES7+ctrl (n=122)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.43783
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.04040
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_HK2+ctrl (n=249)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.92137
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.62782
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_HNF4A+ctrl (n=202)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.79942
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.50434
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_HOXA13+ctrl (n=230)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47865
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10258
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_HOXB9+ctrl (n=356)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48341
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10965
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_HOXC13+ctrl (n=151)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48147
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10676
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_IGDCC3+ZBTB25 (n=99)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22701
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_IGDCC3+ctrl (n=284)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.72575
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.41489
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_IKZF3+ctrl (n=373)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22700
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_IRF1+ctrl (n=331)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.82297
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.52968
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KIF18B+KIF2C (n=83)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.77435
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.47389
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KIF18B+ctrl (n=212)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.94320
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.64960
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KIF2C+ctrl (n=270)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.02233
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.72853
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KLF1+BAK1 (n=323)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.68862
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.36990
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KLF1+CEBPA (n=308)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.38120
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 0.94966
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KLF1+FOXA1 (n=323)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22699
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KLF1+MAP2K6 (n=222)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.71251
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.39885
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KLF1+TGFBR2 (n=263)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.62467
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.29263
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KLF1+ctrl (n=997)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.72410
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.41289
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_KMT2A+ctrl (n=185)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.85563
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.56225
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_LHX1+ELMSAN1 (n=547)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48257
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10840
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_LHX1+ctrl (n=342)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47875
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10274
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_LYL1+ctrl (n=360)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.89406
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.60058
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP2K3+ELMSAN1 (n=484)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.75412
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.44929
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP2K3+IKZF3 (n=220)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57026
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22701
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP2K3+MAP2K6 (n=458)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.91752
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.62397
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP2K3+ctrl (n=458)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.98310
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.68940
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP2K6+ELMSAN1 (n=365)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.89055
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.59707
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP2K6+IKZF3 (n=251)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22700
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP2K6+ctrl (n=363)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.13717
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.84311
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MAP7D1+ctrl (n=277)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.98096
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.68726
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_MIDN+ctrl (n=256)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47343
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.09480
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_NCL+ctrl (n=197)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.96691
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.67324
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_PLK4+ctrl (n=97)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.90855
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.61503
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_POU3F2+ctrl (n=312)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.83007
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.53675
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_PTPN1+ctrl (n=342)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.62145
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.28875
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_PTPN12+UBASH3A (n=255)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22701
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_PTPN12+ZBTB25 (n=257)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22701
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_PTPN12+ctrl (n=194)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.71969
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.40755
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_RUNX1T1+ctrl (n=275)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.02819
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.73437
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SAMD1+PTPN12 (n=292)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22701
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SAMD1+TGFBR2 (n=59)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57008
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22679
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SAMD1+ZBTB1 (n=164)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57020
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22693
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SAMD1+ctrl (n=252)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57285
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.23014
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SGK1+TBX2 (n=287)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.53213
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.17879
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SGK1+TBX3 (n=243)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57025
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22701
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SGK1+ctrl (n=446)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.72552
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.41460
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_SLC6A9+ctrl (n=441)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.81781
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.52453
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TBX2+ctrl (n=269)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.66601
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.34255
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TBX3+TBX2 (n=968)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.53833
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.18699
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TBX3+ctrl (n=289)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.56985
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22651
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TGFBR2+ETS2 (n=275)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.00079
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.70705
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TGFBR2+IGDCC3 (n=262)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.59816
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.26066
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TGFBR2+ctrl (n=209)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.94077
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.64716
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TMSB4X+BAK1 (n=267)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.11310
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.81911
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_TMSB4X+ctrl (n=462)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.22340
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.92919
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_UBASH3A+ctrl (n=371)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.85089
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.55752
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZBTB1+ctrl (n=315)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.64340
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.31524
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZBTB10+DLX2 (n=74)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.43857
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.04157
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZBTB10+ELMSAN1 (n=161)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.46697
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.08512
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZBTB10+PTPN12 (n=230)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.49276
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.12338
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZBTB10+ctrl (n=145)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.46317
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.07938
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZBTB25+ctrl (n=343)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.77690
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.47696
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZC3HAV1+CEBPA (n=123)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.35101
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 0.90011
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZC3HAV1+CEBPE (n=346)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.46011
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.07474
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZC3HAV1+HOXC13 (n=543)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48944
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.11853
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ZC3HAV1+ctrl (n=436)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.04560
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.75174
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl (n=7353)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.00000
#     Avg. New Edges Created (0 -> non-0): 0.00
#     Avg. Strength of New Edges: 0.00000
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+BAK1 (n=637)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.07860
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.78467
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+CEBPA (n=258)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.34225
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 0.88551
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+CEBPE (n=566)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.44962
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.05870
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+DLX2 (n=290)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.47743
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10077
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+ELMSAN1 (n=430)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.93351
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.63992
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+ETS2 (n=656)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.23260
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.93836
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+FEV (n=473)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.64902
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.32203
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+FOXA1 (n=335)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.49299
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.12371
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+FOXF1 (n=266)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.04958
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.75572
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+HOXB9 (n=256)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48341
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10965
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+HOXC13 (n=192)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.48146
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.10676
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+IGDCC3 (n=223)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.72576
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.41490
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+IKZF3 (n=209)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57024
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22699
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+KIF2C (n=248)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.02232
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.72851
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+KLF1 (n=644)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.72409
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.41288
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+MAP2K6 (n=377)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.13715
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.84310
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+MAP7D1 (n=358)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.98095
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.68725
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+PTPN12 (n=164)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.71968
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.40751
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+RUNX1T1 (n=356)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 1.02819
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.73438
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+SAMD1 (n=178)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.57286
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.23015
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+TBX2 (n=295)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.66601
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.34256
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+TBX3 (n=270)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.56986
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.22654
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+TGFBR2 (n=328)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.94077
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.64716
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+UBASH3A (n=315)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.85090
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.55753
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+ZBTB1 (n=287)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.64341
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.31525
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
#
# **Perturbation: Unknown_idx_ctrl+ZBTB25 (n=247)**
#   --- vs. Control Graph ---
#     Avg. Mean Absolute Edge Diff: 0.77690
#     Avg. New Edges Created (0 -> non-0): 1443.00
#     Avg. Strength of New Edges: 1.47695
#     Avg. Edges Lost (non-0 -> 0): 0.00
#   --- vs. Ground Truth Graph ---
#     (No Ground Truth graph loaded for this perturbation)
# -----------------------------------

# %%
gears_mech.node_map_gene = gears_mech.node_map

# %%
import os
import csv
import torch
# F.cosine_similarity and np are not used in this specific function,
# but torch is needed.

def standalone_load_ground_truth_graphs(
    model_G_coexpress,
    node_map_gene,
    node_map_pert,
    device,
    base_path="/kaggle/input/coexpressiongraphs/Downloads/coexpression_graphs", 
    filename="/_42_5045_0.4_20_co_expression_network.csv"
):
    """
    Loads ground truth co-expression graphs from CSV files.

    This function is isolated and does not depend on a class instance.
    It builds a dictionary: {pert_name: 1D_weight_tensor}
    
    Args:
        node_map_gene (dict): A dict {'gene_name': gene_idx}.
        node_map_pert (dict): A dict {'pert_name': pert_idx}.
        device (torch.device or str): The device to create new tensors on.
        base_path (str): Base directory for GT graphs.
        filename (str): Name of the edges file (e.g., "edges.csv").
    """
    print("Attempting to load ground truth co-expression graphs (standalone)...")
    
    # --- 1. Build Edge Index Map ---
    # We use the passed-in arguments directly, no 'self'.
    try:
        edge_index = model_G_coexpress.cpu()
        num_edges = edge_index.shape[1]
        edge_index_map = {}
        for i in range(num_edges):
            u_idx = edge_index[0, i].item()
            v_idx = edge_index[1, i].item()
            edge_index_map[(u_idx, v_idx)] = i
        
        gene_name_to_idx = node_map_gene
        print(f"  Built edge index map for {num_edges} edges.")
    except Exception as e:
        print(f"  Error building edge_index_map: {e}. Aborting GT load.")
        return {}

    # --- 2. Get all perturbation names ---
    pert_names = list(node_map_pert.keys())
    if 'ctrl' not in pert_names:
        pert_names.append('ctrl')

    gt_graph_store = {}
    
    # --- 3. Iterate and load each GT graph file ---
    for pert_name in pert_names:
        file_path = os.path.join(base_path, f"pert_{pert_name}+ctrl", filename)
        
        if not os.path.exists(file_path):
            # print(f"  Info: No GT graph file found for '{pert_name}' at {file_path}. Skipping.")
            continue

        try:
            # Initialize a zero-vector on the specified 'device'
            gt_weights_tensor = torch.zeros(num_edges, device=device)
            
            with open(file_path, 'r', encoding='utf-8') as f:
                reader = csv.reader(f)
                header = next(reader) # Skip header
                
                edges_found = 0
                edges_not_in_index = 0
                
                for row in reader:
                    if len(row) < 3: continue
                    source_name, target_name, weight_str = row[0], row[1], row[2]
                    
                    u_idx = gene_name_to_idx.get(source_name)
                    v_idx = gene_name_to_idx.get(target_name)
                    
                    if u_idx is None or v_idx is None:
                        continue 
                    
                    try:
                        weight = float(weight_str)
                    except ValueError:
                        continue
                    
                    # Check for the edge in our model's edge_index
                    edge_pos = edge_index_map.get((u_idx, v_idx))
                    
                    if edge_pos is not None:
                        gt_weights_tensor[edge_pos] = weight
                        edges_found += 1
                    else:
                        # Optional: Check for reverse edge if graph is undirected
                        edge_pos_rev = edge_index_map.get((v_idx, u_idx))
                        if edge_pos_rev is not None:
                            gt_weights_tensor[edge_pos_rev] = weight
                            edges_found += 1
                        else:
                            edges_not_in_index += 1
            
            gt_graph_store[pert_name] = gt_weights_tensor.detach()
            print(f"  Loaded GT graph for '{pert_name}'. "
                  f"Mapped {edges_found} edges. ({edges_not_in_index} edges from file were not in model's G_coexpress).")

        except Exception as e:
            print(f"  Error loading GT graph for '{pert_name}' from {file_path}: {e}")

    print(f"Successfully loaded {len(gt_graph_store)} ground truth graphs.")
    return gt_graph_store

# %%
# Assuming 'gears_mech' is your object instance
# and it has the required attributes.

# Pass the attributes from the gears_mech object into the standalone function
ground_truth_data = standalone_load_ground_truth_graphs(
    model_G_coexpress = gears_mech.model.G_coexpress,
    node_map_gene     = gears_mech.node_map_gene,
    node_map_pert     = gears_mech.node_map_pert,
    device            = gears_mech.device
)
print(ground_truth_data.keys())
# Out:
# Attempting to load ground truth co-expression graphs (standalone)...
#   Built edge index map for 7802 edges.
#   Loaded GT graph for 'AHR'. Mapped 2781 edges. (8313 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ARID1A'. Mapped 2391 edges. (13790 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ARRDC3'. Mapped 2371 edges. (6273 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ATL1'. Mapped 2418 edges. (7687 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'BAK1'. Mapped 2512 edges. (4800 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'BCL2L11'. Mapped 2453 edges. (6141 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'BCORL1'. Mapped 2495 edges. (6319 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'BPGM'. Mapped 2393 edges. (7154 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'C19orf26'. Mapped 2530 edges. (5750 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'C3orf72'. Mapped 2364 edges. (10795 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CBFA2T3'. Mapped 2374 edges. (8776 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CBL'. Mapped 2619 edges. (6195 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CDKN1A'. Mapped 2398 edges. (14848 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CDKN1B'. Mapped 2764 edges. (12388 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CDKN1C'. Mapped 2516 edges. (15978 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CEBPA'. Mapped 2738 edges. (8712 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CEBPB'. Mapped 2654 edges. (11988 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CEBPE'. Mapped 3021 edges. (8289 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CELF2'. Mapped 2710 edges. (8792 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CITED1'. Mapped 2386 edges. (14085 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CKS1B'. Mapped 2165 edges. (10874 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CLDN6'. Mapped 2486 edges. (10548 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CNN1'. Mapped 2095 edges. (7343 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CNNM4'. Mapped 2362 edges. (6616 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'COL1A1'. Mapped 2439 edges. (8699 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'COL2A1'. Mapped 2533 edges. (10172 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'CSRNP1'. Mapped 2449 edges. (8190 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'DLX2'. Mapped 2431 edges. (9015 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'DUSP9'. Mapped 2726 edges. (5608 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'EGR1'. Mapped 2319 edges. (8631 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ELMSAN1'. Mapped 2365 edges. (7490 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ETS2'. Mapped 2384 edges. (5802 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'FEV'. Mapped 2025 edges. (9527 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'FOSB'. Mapped 2865 edges. (8169 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'FOXA1'. Mapped 2595 edges. (6656 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'FOXA3'. Mapped 2660 edges. (7999 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'FOXF1'. Mapped 2520 edges. (7216 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'FOXL2'. Mapped 2432 edges. (8495 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'FOXO4'. Mapped 2334 edges. (11718 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'GLB1L2'. Mapped 2594 edges. (7045 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'HES7'. Mapped 2254 edges. (17862 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'HK2'. Mapped 2200 edges. (9285 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'HNF4A'. Mapped 2364 edges. (10795 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'HOXA13'. Mapped 2504 edges. (10175 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'HOXB9'. Mapped 2624 edges. (9541 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'HOXC13'. Mapped 2324 edges. (13742 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'IGDCC3'. Mapped 2466 edges. (8169 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'IKZF3'. Mapped 2693 edges. (8945 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'IRF1'. Mapped 2770 edges. (8994 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ISL2'. Mapped 2256 edges. (6757 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'JUN'. Mapped 2295 edges. (9805 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'KIF18B'. Mapped 2225 edges. (10057 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'KIF2C'. Mapped 2263 edges. (8138 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'KLF1'. Mapped 2992 edges. (4798 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'KMT2A'. Mapped 2083 edges. (10052 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'LHX1'. Mapped 2609 edges. (9798 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'LYL1'. Mapped 2398 edges. (7201 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MAML2'. Mapped 2520 edges. (5941 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MAP2K3'. Mapped 2593 edges. (6555 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MAP2K6'. Mapped 2438 edges. (7322 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MAP4K3'. Mapped 2346 edges. (7915 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MAP4K5'. Mapped 2283 edges. (8020 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MAP7D1'. Mapped 2370 edges. (9404 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MAPK1'. Mapped 2247 edges. (6525 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MEIS1'. Mapped 2348 edges. (8589 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'MIDN'. Mapped 2577 edges. (11234 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'NCL'. Mapped 2231 edges. (12411 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'NIT1'. Mapped 2341 edges. (16089 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'OSR2'. Mapped 2840 edges. (10552 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'PLK4'. Mapped 2036 edges. (20141 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'POU3F2'. Mapped 2276 edges. (6536 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'PRDM1'. Mapped 2360 edges. (10236 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'PRTG'. Mapped 2527 edges. (8740 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'PTPN1'. Mapped 2473 edges. (7386 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'PTPN12'. Mapped 2162 edges. (10051 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'PTPN13'. Mapped 2316 edges. (10150 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'PTPN9'. Mapped 2049 edges. (10431 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'RREB1'. Mapped 2330 edges. (8062 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'RUNX1T1'. Mapped 2247 edges. (7279 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'S1PR2'. Mapped 2632 edges. (8153 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'SAMD1'. Mapped 2539 edges. (11451 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'SET'. Mapped 2628 edges. (6682 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'SGK1'. Mapped 2527 edges. (6505 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'SLC4A1'. Mapped 2894 edges. (6830 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'SLC6A9'. Mapped 2653 edges. (7935 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'SNAI1'. Mapped 2389 edges. (10831 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'SPI1'. Mapped 2348 edges. (12740 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'STIL'. Mapped 2167 edges. (17949 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'TBX2'. Mapped 2443 edges. (9325 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'TBX3'. Mapped 2411 edges. (9907 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'TGFBR2'. Mapped 2205 edges. (9131 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'TMSB4X'. Mapped 2529 edges. (6882 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'TP73'. Mapped 2581 edges. (12979 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'TSC22D1'. Mapped 2441 edges. (7085 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'UBASH3A'. Mapped 2542 edges. (7831 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'UBASH3B'. Mapped 2448 edges. (6041 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ZBTB1'. Mapped 2445 edges. (7967 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ZBTB10'. Mapped 2367 edges. (16759 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ZBTB25'. Mapped 2339 edges. (6203 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ZC3HAV1'. Mapped 2437 edges. (6996 edges from file were not in model's G_coexpress).
#   Loaded GT graph for 'ZNF318'. Mapped 2708 edges. (7377 edges from file were not in model's G_coexpress).
# Successfully loaded 101 ground truth graphs.
# dict_keys(['AHR', 'ARID1A', 'ARRDC3', 'ATL1', 'BAK1', 'BCL2L11', 'BCORL1', 'BPGM', 'C19orf26', 'C3orf72', 'CBFA2T3', 'CBL', 'CDKN1A', 'CDKN1B', 'CDKN1C', 'CEBPA', 'CEBPB', 'CEBPE', 'CELF2', 'CITED1', 'CKS1B', 'CLDN6', 'CNN1', 'CNNM4', 'COL1A1', 'COL2A1', 'CSRNP1', 'DLX2', 'DUSP9', 'EGR1', 'ELMSAN1', 'ETS2', 'FEV', 'FOSB', 'FOXA1', 'FOXA3', 'FOXF1', 'FOXL2', 'FOXO4', 'GLB1L2', 'HES7', 'HK2', 'HNF4A', 'HOXA13', 'HOXB9', 'HOXC13', 'IGDCC3', 'IKZF3', 'IRF1', 'ISL2', 'JUN', 'KIF18B', 'KIF2C', 'KLF1', 'KMT2A', 'LHX1', 'LYL1', 'MAML2', 'MAP2K3', 'MAP2K6', 'MAP4K3', 'MAP4K5', 'MAP7D1', 'MAPK1', 'MEIS1', 'MIDN', 'NCL', 'NIT1', 'OSR2', 'PLK4', 'POU3F2', 'PRDM1', 'PRTG', 'PTPN1', 'PTPN12', 'PTPN13', 'PTPN9', 'RREB1', 'RUNX1T1', 'S1PR2', 'SAMD1', 'SET', 'SGK1', 'SLC4A1', 'SLC6A9', 'SNAI1', 'SPI1', 'STIL', 'TBX2', 'TBX3', 'TGFBR2', 'TMSB4X', 'TP73', 'TSC22D1', 'UBASH3A', 'UBASH3B', 'ZBTB1', 'ZBTB10', 'ZBTB25', 'ZC3HAV1', 'ZNF318'])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def plot_gt_comparison_results(results_store):
    """
    Generates a box plot visualizing the distribution of Pearson and
    Cosine similarity scores for each perturbation.

    Args:
        results_store: The dictionary returned by 
                         compare_graphs_to_ground_truth().
    """
    
    # --- 1. Convert data to a long-form DataFrame (ideal for seaborn) ---
    plot_data = []
    for pert_name, stats in results_store.items():
        # Add Pearson scores
        for score in stats['gt_pearson_corr']:
            if not np.isnan(score):
                plot_data.append({
                    'pert_name': pert_name,
                    'metric': 'Pearson',
                    'value': score
                })
        
        # Add Cosine scores
        for score in stats['gt_cos_sim']:
            if not np.isnan(score):
                plot_data.append({
                    'pert_name': pert_name,
                    'metric': 'Cosine',
                    'value': score
                })

    if not plot_data:
        print("No valid Ground Truth data found to plot.")
        return

    df = pd.DataFrame(plot_data)

    # --- 2. Determine plot sorting and size ---
    # Sort perturbations by median Pearson score (descending)
    # This makes the plot much easier to read.
    sorted_perts = df[df['metric'] == 'Pearson'] \
                    .groupby('pert_name')['value'] \
                    .median() \
                    .sort_values(ascending=False) \
                    .index
    
    # Dynamically adjust plot size
    num_perts = len(sorted_perts)
    plot_width = max(10, num_perts * 0.8) # Adjust 0.8 as needed
    plot_height = 7
    
    # --- 3. Create the Plot ---
    print("Generating plot...")
    plt.figure(figsize=(plot_width, plot_height))
    
    sns.boxplot(
        data=df,
        x='pert_name',
        y='value',
        hue='metric',
        order=sorted_perts,  # Use the sorted order
        palette="Set2"
    )
    
    plt.title('Distribution of Predicted vs. Ground Truth Similarity', fontsize=16)
    plt.ylabel('Similarity Score', fontsize=12)
    plt.xlabel('Perturbation', fontsize=12)
    plt.xticks(rotation=90) # Rotate labels for readability
    plt.legend(title='Metric', bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    
    plt.show()

# %%
import torch
import torch.nn.functional as F
import numpy as np

def compare_graphs_to_ground_truth(gears_object, dataloader, ground_truth_data):
    """
    Analyzes and compares predicted graph edge weights ONLY
    against the corresponding ground truth co-expression graphs.

    Args:
        gears_object: The instance of your GEA-RS class (e.g., 'gears_mech').
        dataloader: The dataloader to iterate over for analysis.
        ground_truth_data (dict): The pre-loaded GT graph data from your
                                  standalone_load_ground_truth_graphs() function.
                                  Format: { 'pert_name_1': tensor, ... }
    """
    
    print("Starting graph comparison analysis (vs. Ground Truth)...")
    
    # --- 1. Check passed-in GT data ---
    if not ground_truth_data or not isinstance(ground_truth_data, dict):
        print("Error: The provided 'ground_truth_data' is not a valid"
              " or is an empty dictionary. Aborting.")
        return {}
    else:
        print(f"  Successfully received pre-loaded data for "
              f"{len(ground_truth_data)} GT graphs.")
    
    # --- 2. Get num_edges for shape comparison ---
    try:
        num_edges = gears_object.model.G_coexpress.shape[1]
    except AttributeError:
        print("Error: `gears_object.model.G_coexpress` not found. Aborting.")
        return {}

    # --- 3. Create Perturbation Name Map ---
    try:
        idx_to_pert_name = {v: k for k, v in gears_object.node_map_pert.items()}
        idx_to_pert_name[-1] = 'ctrl'
        # print(idx_to_pert_name)
    except AttributeError:
        print("Error: `gears_object.node_map_pert` not found. Aborting.")
        return {}

    # Dictionary to store aggregated results
    results_store = {}

    # --- 4. Iterate Through Dataloader ---
    for step, batch in enumerate(dataloader):
        with torch.no_grad():
            batch.to(gears_object.device)
            
            # Run the model
            pred, graph_data = gears_object.model.compute_graphs(batch)

            # --- 5. Get Predicted Graphs and Labels ---
            predicted_graphs_list = graph_data.get("graphs")
            if predicted_graphs_list is None or not isinstance(predicted_graphs_list, list):
                print(f"Error: 'graphs' key not in model output. Aborting batch {step}.")
                continue
            
            num_graphs_in_batch = len(predicted_graphs_list)
            pert_indices = np.array(batch.pert) 

            if num_graphs_in_batch != pert_indices.shape[0]:
                print(f"Warning: Mismatch in batch {step}. Skipping.")
                continue

            # --- 6. Compare Each Graph in Batch ---
            for i in range(num_graphs_in_batch):
                
                pert_idx = batch.pert_idx[i]
                pert_name = idx_to_pert_name[pert_idx[0]]
                
                data_graph_i = predicted_graphs_list[i]
                predicted_weights_graph_i = data_graph_i.edge_weight.detach()
                
                if predicted_weights_graph_i.shape[0] != num_edges:
                    print(f"Warning: Shape mismatch for {pert_name}. Skipping graph.")
                    continue
                
                # --- 7. Comparison vs. Ground Truth ---
                # MODIFIED: Uses the passed-in dictionary, not self.gt_graph_store
                try:
                    gt_weights = ground_truth_data[f"{pert_name}"]
                    # gt_weights = ground_truth_data[f"Unknown_idx_{pert_name}+ctrl"]
                except:
                    pass 
                
                gt_pearson_corr = np.nan
                gt_cos_sim = np.nan
                
                if gt_weights is not None:
                    if gt_weights.shape[0] == num_edges:
                        # Call the helper function from the gears_object
                        gt_pearson_corr = gears_object.calculate_pearson(
                            predicted_weights_graph_i, gt_weights
                        )
                        
                        gt_cos_sim = F.cosine_similarity(
                            predicted_weights_graph_i.unsqueeze(0), 
                            gt_weights.unsqueeze(0)
                        ).item()
                    else:
                        print(f"Warning: GT graph for {pert_name} shape mismatch. Skipping.")
                
                # --- 8. Store Results ---
                if pert_name not in results_store:
                    results_store[pert_name] = {
                        'count': 0,
                        'gt_pearson_corr': [],
                        'gt_cos_sim': []
                    }
                
                results_store[pert_name]['count'] += 1
                results_store[pert_name]['gt_pearson_corr'].append(gt_pearson_corr)
                results_store[pert_name]['gt_cos_sim'].append(gt_cos_sim)

    # --- 9. Print Final Aggregated Report (Unchanged) ---
    print("\n--- 📊 Ground Truth Comparison Report ---")
    
    for pert_name in sorted(results_store.keys(), key=lambda x: (x == 'ctrl', x)):
        stats = results_store[pert_name]
        count = stats['count']
        
        avg_gt_pearson = np.nanmean(stats['gt_pearson_corr'])
        avg_gt_cos_sim = np.nanmean(stats['gt_cos_sim'])

        print(f"\n**Perturbation: {pert_name} (n={count})**")
        if not np.isnan(avg_gt_pearson):
            print(f"    Avg. Pearson Correlation: {avg_gt_pearson:.4f}")
            print(f"    Avg. Cosine Similarity: {avg_gt_cos_sim:.4f}")
        else:
            print(f"    (No Ground Truth graph loaded for this perturbation)")

    print("-----------------------------------")
    return results_store

# %%
gt_results.keys()
# Out:
# dict_keys(['Unknown_idx_BAK1+ctrl', 'Unknown_idx_MAP2K3+MAP2K6', 'Unknown_idx_ctrl', 'Unknown_idx_TBX3+TBX2', 'Unknown_idx_ctrl+FOXA1', 'Unknown_idx_FOSB+CEBPE', 'Unknown_idx_ctrl+KLF1', 'Unknown_idx_FOXO4+ctrl', 'Unknown_idx_ctrl+HOXC13', 'Unknown_idx_ctrl+FOXF1', 'Unknown_idx_UBASH3A+ctrl', 'Unknown_idx_PTPN1+ctrl', 'Unknown_idx_FOXA1+ctrl', 'Unknown_idx_TGFBR2+ctrl', 'Unknown_idx_SGK1+TBX3', 'Unknown_idx_ZC3HAV1+CEBPE', 'Unknown_idx_ctrl+TBX2', 'Unknown_idx_ZC3HAV1+HOXC13', 'Unknown_idx_CEBPE+ctrl', 'Unknown_idx_ZC3HAV1+ctrl', 'Unknown_idx_MAP2K6+IKZF3', 'Unknown_idx_PTPN12+ZBTB25', 'Unknown_idx_FOXA3+FOXF1', 'Unknown_idx_IKZF3+ctrl', 'Unknown_idx_KLF1+FOXA1', 'Unknown_idx_ARRDC3+ctrl', 'Unknown_idx_KLF1+BAK1', 'Unknown_idx_MAP2K6+ctrl', 'Unknown_idx_ctrl+CEBPE', 'Unknown_idx_SAMD1+ctrl', 'Unknown_idx_FOXA3+ctrl', 'Unknown_idx_ETS2+IGDCC3', 'Unknown_idx_LHX1+ctrl', 'Unknown_idx_KIF18B+ctrl', 'Unknown_idx_ZBTB10+PTPN12', 'Unknown_idx_PLK4+ctrl', 'Unknown_idx_ETS2+IKZF3', 'Unknown_idx_FOSB+IKZF3', 'Unknown_idx_FOSB+PTPN12', 'Unknown_idx_FOXA3+FOXA1', 'Unknown_idx_POU3F2+ctrl', 'Unknown_idx_NCL+ctrl', 'Unknown_idx_ctrl+IKZF3', 'Unknown_idx_SGK1+ctrl', 'Unknown_idx_TMSB4X+ctrl', 'Unknown_idx_ctrl+ELMSAN1', 'Unknown_idx_ctrl+ETS2', 'Unknown_idx_MAP2K3+IKZF3', 'Unknown_idx_KLF1+CEBPA', 'Unknown_idx_SLC6A9+ctrl', 'Unknown_idx_ctrl+HOXB9', 'Unknown_idx_ctrl+TBX3', 'Unknown_idx_PTPN12+UBASH3A', 'Unknown_idx_MAP2K3+ctrl', 'Unknown_idx_CSRNP1+ctrl', 'Unknown_idx_ZC3HAV1+CEBPA', 'Unknown_idx_ctrl+ZBTB25', 'Unknown_idx_ctrl+BAK1', 'Unknown_idx_LYL1+ctrl', 'Unknown_idx_CEBPE+KLF1', 'Unknown_idx_KLF1+ctrl', 'Unknown_idx_CEBPE+PTPN12', 'Unknown_idx_ZBTB10+DLX2', 'Unknown_idx_GLB1L2+ctrl', 'Unknown_idx_SAMD1+ZBTB1', 'Unknown_idx_ctrl+RUNX1T1', 'Unknown_idx_CEBPE+RUNX1T1', 'Unknown_idx_ctrl+UBASH3A', 'Unknown_idx_LHX1+ELMSAN1', 'Unknown_idx_RUNX1T1+ctrl', 'Unknown_idx_ELMSAN1+ctrl', 'Unknown_idx_ETS2+MAP7D1', 'Unknown_idx_MAP7D1+ctrl', 'Unknown_idx_TBX2+ctrl', 'Unknown_idx_ATL1+ctrl', 'Unknown_idx_HNF4A+ctrl', 'Unknown_idx_PTPN12+ctrl', 'Unknown_idx_FOSB+ctrl', 'Unknown_idx_ctrl+MAP2K6', 'Unknown_idx_CEBPE+CEBPA', 'Unknown_idx_DLX2+ctrl', 'Unknown_idx_MIDN+ctrl', 'Unknown_idx_ctrl+FEV', 'Unknown_idx_ctrl+PTPN12', 'Unknown_idx_MAP2K3+ELMSAN1', 'Unknown_idx_TBX3+ctrl', 'Unknown_idx_HOXC13+ctrl', 'Unknown_idx_FOXA1+FOXF1', 'Unknown_idx_ctrl+CEBPA', 'Unknown_idx_FOXF1+HOXB9', 'Unknown_idx_ctrl+SAMD1', 'Unknown_idx_ctrl+MAP7D1', 'Unknown_idx_ctrl+DLX2', 'Unknown_idx_ctrl+KIF2C', 'Unknown_idx_ctrl+ZBTB1', 'Unknown_idx_TGFBR2+IGDCC3', 'Unknown_idx_ZBTB10+ELMSAN1', 'Unknown_idx_HOXA13+ctrl', 'Unknown_idx_CEBPA+ctrl', 'Unknown_idx_TGFBR2+ETS2', 'Unknown_idx_ZBTB25+ctrl', 'Unknown_idx_ctrl+TGFBR2', 'Unknown_idx_HES7+ctrl', 'Unknown_idx_ZBTB1+ctrl', 'Unknown_idx_FEV+ctrl', 'Unknown_idx_TMSB4X+BAK1', 'Unknown_idx_FOXA1+HOXB9', 'Unknown_idx_ETS2+CEBPE', 'Unknown_idx_ctrl+IGDCC3', 'Unknown_idx_COL1A1+ctrl', 'Unknown_idx_FOXA3+HOXB9', 'Unknown_idx_ZBTB10+ctrl', 'Unknown_idx_KMT2A+ctrl', 'Unknown_idx_MAP2K6+ELMSAN1', 'Unknown_idx_ETS2+ctrl', 'Unknown_idx_SGK1+TBX2', 'Unknown_idx_KIF2C+ctrl', 'Unknown_idx_HOXB9+ctrl', 'Unknown_idx_SAMD1+PTPN12', 'Unknown_idx_IGDCC3+ZBTB25', 'Unknown_idx_KLF1+MAP2K6', 'Unknown_idx_KLF1+TGFBR2', 'Unknown_idx_HK2+ctrl', 'Unknown_idx_IRF1+ctrl', 'Unknown_idx_FOXF1+ctrl', 'Unknown_idx_FEV+MAP7D1', 'Unknown_idx_KIF18B+KIF2C', 'Unknown_idx_IGDCC3+ctrl', 'Unknown_idx_SAMD1+TGFBR2'])

# %%
# Assuming 'gears_mech' is your object and 'val_dataloader' is your dataloader

# 1. Run the analysis and get the results
#    (This assumes gears_mech has the patched helper methods)
gt_results = compare_graphs_to_ground_truth(gears_mech, gears_mech.dataloader["train_loader"],ground_truth_data )

# 2. Plot the results
#    (This will show a box plot of Pearson and Cosine scores)

plot_gt_comparison_results(gt_results)
# Out:
# Starting graph comparison analysis (vs. Ground Truth)...
#   Successfully received pre-loaded data for 101 GT graphs.
#
# --- 📊 Ground Truth Comparison Report ---
#
# **Perturbation: ARRDC3 (n=405)**
#     Avg. Pearson Correlation: 0.0079
#     Avg. Cosine Similarity: 0.5344
#
# **Perturbation: ATL1 (n=305)**
#     Avg. Pearson Correlation: 0.0092
#     Avg. Cosine Similarity: 0.5275
#
# **Perturbation: BAK1 (n=1171)**
#     Avg. Pearson Correlation: 0.0087
#     Avg. Cosine Similarity: 0.5505
#
# **Perturbation: CEBPA (n=580)**
#     Avg. Pearson Correlation: 0.0014
#     Avg. Cosine Similarity: 0.5523
#
# **Perturbation: CEBPE (n=3015)**
#     Avg. Pearson Correlation: 0.0091
#     Avg. Cosine Similarity: 0.5819
#
# **Perturbation: COL1A1 (n=257)**
#     Avg. Pearson Correlation: 0.0072
#     Avg. Cosine Similarity: 0.5265
#
# **Perturbation: CSRNP1 (n=354)**
#     Avg. Pearson Correlation: 0.0060
#     Avg. Cosine Similarity: 0.5401
#
# **Perturbation: DLX2 (n=606)**
#     Avg. Pearson Correlation: -0.0027
#     Avg. Cosine Similarity: 0.5252
#
# **Perturbation: ELMSAN1 (n=783)**
#     Avg. Pearson Correlation: 0.0085
#     Avg. Cosine Similarity: 0.5319
#
# **Perturbation: ETS2 (n=2369)**
#     Avg. Pearson Correlation: 0.0086
#     Avg. Cosine Similarity: 0.5336
#
# **Perturbation: FEV (n=893)**
#     Avg. Pearson Correlation: 0.0127
#     Avg. Cosine Similarity: 0.4888
#
# **Perturbation: FOSB (n=1139)**
#     Avg. Pearson Correlation: 0.0092
#     Avg. Cosine Similarity: 0.5721
#
# **Perturbation: FOXA1 (n=1264)**
#     Avg. Pearson Correlation: 0.0039
#     Avg. Cosine Similarity: 0.5445
#
# **Perturbation: FOXA3 (n=1037)**
#     Avg. Pearson Correlation: 0.0023
#     Avg. Cosine Similarity: 0.5496
#
# **Perturbation: FOXF1 (n=888)**
#     Avg. Pearson Correlation: 0.0106
#     Avg. Cosine Similarity: 0.5477
#
# **Perturbation: FOXO4 (n=189)**
#     Avg. Pearson Correlation: 0.0107
#     Avg. Cosine Similarity: 0.5150
#
# **Perturbation: GLB1L2 (n=378)**
#     Avg. Pearson Correlation: 0.0021
#     Avg. Cosine Similarity: 0.5522
#
# **Perturbation: HES7 (n=122)**
#     Avg. Pearson Correlation: -0.0048
#     Avg. Cosine Similarity: 0.5003
#
# **Perturbation: HK2 (n=249)**
#     Avg. Pearson Correlation: 0.0032
#     Avg. Cosine Similarity: 0.5127
#
# **Perturbation: HNF4A (n=202)**
#     Avg. Pearson Correlation: 0.0084
#     Avg. Cosine Similarity: 0.5254
#
# **Perturbation: HOXA13 (n=230)**
#     Avg. Pearson Correlation: -0.0052
#     Avg. Cosine Similarity: 0.5301
#
# **Perturbation: HOXB9 (n=611)**
#     Avg. Pearson Correlation: 0.0039
#     Avg. Cosine Similarity: 0.5479
#
# **Perturbation: HOXC13 (n=343)**
#     Avg. Pearson Correlation: 0.0021
#     Avg. Cosine Similarity: 0.5105
#
# **Perturbation: IGDCC3 (n=606)**
#     Avg. Pearson Correlation: 0.0087
#     Avg. Cosine Similarity: 0.5346
#
# **Perturbation: IKZF3 (n=583)**
#     Avg. Pearson Correlation: 0.0121
#     Avg. Cosine Similarity: 0.5563
#
# **Perturbation: IRF1 (n=331)**
#     Avg. Pearson Correlation: 0.0036
#     Avg. Cosine Similarity: 0.5668
#
# **Perturbation: KIF18B (n=295)**
#     Avg. Pearson Correlation: 0.0079
#     Avg. Cosine Similarity: 0.5150
#
# **Perturbation: KIF2C (n=518)**
#     Avg. Pearson Correlation: 0.0056
#     Avg. Cosine Similarity: 0.5220
#
# **Perturbation: KLF1 (n=3080)**
#     Avg. Pearson Correlation: 0.0054
#     Avg. Cosine Similarity: 0.5921
#
# **Perturbation: KMT2A (n=185)**
#     Avg. Pearson Correlation: 0.0071
#     Avg. Cosine Similarity: 0.4988
#
# **Perturbation: LHX1 (n=888)**
#     Avg. Pearson Correlation: 0.0054
#     Avg. Cosine Similarity: 0.5467
#
# **Perturbation: LYL1 (n=360)**
#     Avg. Pearson Correlation: 0.0031
#     Avg. Cosine Similarity: 0.5339
#
# **Perturbation: MAP2K3 (n=1620)**
#     Avg. Pearson Correlation: 0.0055
#     Avg. Cosine Similarity: 0.5524
#
# **Perturbation: MAP2K6 (n=1357)**
#     Avg. Pearson Correlation: -0.0027
#     Avg. Cosine Similarity: 0.5361
#
# **Perturbation: MAP7D1 (n=635)**
#     Avg. Pearson Correlation: 0.0026
#     Avg. Cosine Similarity: 0.5299
#
# **Perturbation: MIDN (n=256)**
#     Avg. Pearson Correlation: 0.0080
#     Avg. Cosine Similarity: 0.5395
#
# **Perturbation: NCL (n=197)**
#     Avg. Pearson Correlation: 0.0041
#     Avg. Cosine Similarity: 0.5143
#
# **Perturbation: PLK4 (n=97)**
#     Avg. Pearson Correlation: 0.0099
#     Avg. Cosine Similarity: 0.4896
#
# **Perturbation: POU3F2 (n=312)**
#     Avg. Pearson Correlation: 0.0047
#     Avg. Cosine Similarity: 0.5194
#
# **Perturbation: PTPN1 (n=342)**
#     Avg. Pearson Correlation: 0.0041
#     Avg. Cosine Similarity: 0.5334
#
# **Perturbation: PTPN12 (n=870)**
#     Avg. Pearson Correlation: 0.0077
#     Avg. Cosine Similarity: 0.5029
#
# **Perturbation: RUNX1T1 (n=631)**
#     Avg. Pearson Correlation: 0.0029
#     Avg. Cosine Similarity: 0.5187
#
# **Perturbation: SAMD1 (n=945)**
#     Avg. Pearson Correlation: 0.0092
#     Avg. Cosine Similarity: 0.5379
#
# **Perturbation: SGK1 (n=976)**
#     Avg. Pearson Correlation: 0.0123
#     Avg. Cosine Similarity: 0.5450
#
# **Perturbation: SLC6A9 (n=441)**
#     Avg. Pearson Correlation: 0.0046
#     Avg. Cosine Similarity: 0.5601
#
# **Perturbation: TBX2 (n=564)**
#     Avg. Pearson Correlation: 0.0032
#     Avg. Cosine Similarity: 0.5333
#
# **Perturbation: TBX3 (n=1528)**
#     Avg. Pearson Correlation: 0.0030
#     Avg. Cosine Similarity: 0.5265
#
# **Perturbation: TGFBR2 (n=1074)**
#     Avg. Pearson Correlation: 0.0071
#     Avg. Cosine Similarity: 0.5092
#
# **Perturbation: TMSB4X (n=729)**
#     Avg. Pearson Correlation: 0.0053
#     Avg. Cosine Similarity: 0.5524
#
# **Perturbation: UBASH3A (n=686)**
#     Avg. Pearson Correlation: 0.0045
#     Avg. Cosine Similarity: 0.5490
#
# **Perturbation: ZBTB1 (n=602)**
#     Avg. Pearson Correlation: 0.0080
#     Avg. Cosine Similarity: 0.5342
#
# **Perturbation: ZBTB10 (n=610)**
#     Avg. Pearson Correlation: -0.0067
#     Avg. Cosine Similarity: 0.5150
#
# **Perturbation: ZBTB25 (n=590)**
#     Avg. Pearson Correlation: 0.0114
#     Avg. Cosine Similarity: 0.5273
#
# **Perturbation: ZC3HAV1 (n=1449)**
#     Avg. Pearson Correlation: 0.0031
#     Avg. Cosine Similarity: 0.5343
#
# **Perturbation: ctrl (n=7349)**
#     Avg. Pearson Correlation: 0.4226
#     Avg. Cosine Similarity: 0.6594
# -----------------------------------
# Generating plot...

# %%
import torch
import torch.nn.functional as F
import numpy as np

def compare_control_to_ground_truth(gears_object, ground_truth_data):
    """
    Compares the model's single BASELINE CONTROL graph (G_coexpress_weight)
    against every Ground Truth graph provided.

    This helps establish a baseline for how "different" the GT graphs
    are from the control, using the control's own logic.

    Args:
        gears_object: The instance of your GEA-RS class (e.g., 'gears_mech').
                      Must have .model.G_coexpress_weight, .device,
                      and .calculate_pearson().
        ground_truth_data (dict): The pre-loaded GT graph data.
                                  Format: { 'pert_name_1': tensor, ... }
    """
    
    print("Starting static analysis: BASELINE CONTROL vs. All Ground Truths...")
    
    # --- 1. Get the Baseline Control Graph ---
    try:
        # This is the single baseline graph from the model
        control_weights = gears_object.model.G_coexpress_weight.to(gears_object.device).detach()
        num_edges = control_weights.shape[0]
        print(f"  Loaded baseline control graph with {num_edges} edges.")
    except AttributeError:
        print("Error: `gears_object.model.G_coexpress_weight` not found. Aborting.")
        return {}

    # --- 2. Check passed-in GT data ---
    if not ground_truth_data or not isinstance(ground_truth_data, dict):
        print("Error: The provided 'ground_truth_data' is not a valid"
              " or is an empty dictionary. Aborting.")
        return {}
    else:
        print(f"  Comparing against {len(ground_truth_data)} pre-loaded GT graphs.")

    # Dictionary to store results
    results_store = {}

    # --- 3. Iterate Through All GT Graphs and Compare ---
    for pert_name, gt_weights in ground_truth_data.items():
        
        # --- 3a. Sanity Check Shapes ---
        if gt_weights.shape[0] != num_edges:
            print(f"Warning: Shape mismatch for GT graph '{pert_name}' "
                  f"({gt_weights.shape[0]} vs {num_edges}). Skipping.")
            continue
            
        # --- 3b. Calculate Metrics ---
        
        # Call the helper function from the gears_object
        pearson_corr = gears_object.calculate_pearson(
            control_weights, gt_weights
        )
        
        cos_sim = F.cosine_similarity(
            control_weights.unsqueeze(0), 
            gt_weights.unsqueeze(0)
        ).item()
        
        # --- 3c. Store Results ---
        results_store[pert_name] = {
            'pearson': pearson_corr,
            'cosine': cos_sim
        }

    # --- 4. Print Final Aggregated Report ---
    print("\n--- 📊 Baseline Control vs. GT Report ---")
    
    # Sort to put 'ctrl' first, then alphabetically
    for pert_name in sorted(results_store.keys(), key=lambda x: (x == 'ctrl', x)):
        stats = results_store[pert_name]
        
        print(f"\n**Baseline Control vs. GT '{pert_name}'**")
        print(f"    Pearson Correlation: {stats['pearson']:.4f}")
        print(f"    Cosine Similarity:   {stats['cosine']:.4f}")
        
        if pert_name == 'ctrl':
            print("    (This is the similarity between the model's baseline"
                  " and the ground-truth control)")

    print("-----------------------------------")
    return results_store

# %%
len(ground_truth_data["AHR"])
# Out:
# 7802

# %%
# --- STEP 3: Run Baseline Comparison (Control vs. GT) ---
print("\nStep 3: Running baseline analysis (Control vs. GT)...")
baseline_results = compare_control_to_ground_truth(
    gears_mech,
    ground_truth_data
)
# Out:
# Step 3: Running baseline analysis (Control vs. GT)...
# Starting static analysis: BASELINE CONTROL vs. All Ground Truths...
#   Loaded baseline control graph with 7802 edges.
#   Comparing against 101 pre-loaded GT graphs.
#
# --- 📊 Baseline Control vs. GT Report ---
#
# **Baseline Control vs. GT 'AHR'**
#     Pearson Correlation: 0.4395
#     Cosine Similarity:   0.6848
#
# **Baseline Control vs. GT 'ARID1A'**
#     Pearson Correlation: 0.3651
#     Cosine Similarity:   0.6216
#
# **Baseline Control vs. GT 'ARRDC3'**
#     Pearson Correlation: 0.4349
#     Cosine Similarity:   0.6543
#
# **Baseline Control vs. GT 'ATL1'**
#     Pearson Correlation: 0.3889
#     Cosine Similarity:   0.6339
#
# **Baseline Control vs. GT 'BAK1'**
#     Pearson Correlation: 0.4447
#     Cosine Similarity:   0.6693
#
# **Baseline Control vs. GT 'BCL2L11'**
#     Pearson Correlation: 0.4345
#     Cosine Similarity:   0.6602
#
# **Baseline Control vs. GT 'BCORL1'**
#     Pearson Correlation: 0.4345
#     Cosine Similarity:   0.6622
#
# **Baseline Control vs. GT 'BPGM'**
#     Pearson Correlation: 0.4244
#     Cosine Similarity:   0.6505
#
# **Baseline Control vs. GT 'C19orf26'**
#     Pearson Correlation: 0.4349
#     Cosine Similarity:   0.6653
#
# **Baseline Control vs. GT 'C3orf72'**
#     Pearson Correlation: 0.3862
#     Cosine Similarity:   0.6282
#
# **Baseline Control vs. GT 'CBFA2T3'**
#     Pearson Correlation: 0.4176
#     Cosine Similarity:   0.6449
#
# **Baseline Control vs. GT 'CBL'**
#     Pearson Correlation: 0.4468
#     Cosine Similarity:   0.6776
#
# **Baseline Control vs. GT 'CDKN1A'**
#     Pearson Correlation: 0.3541
#     Cosine Similarity:   0.6167
#
# **Baseline Control vs. GT 'CDKN1B'**
#     Pearson Correlation: 0.3695
#     Cosine Similarity:   0.6520
#
# **Baseline Control vs. GT 'CDKN1C'**
#     Pearson Correlation: 0.3805
#     Cosine Similarity:   0.6387
#
# **Baseline Control vs. GT 'CEBPA'**
#     Pearson Correlation: 0.4270
#     Cosine Similarity:   0.6770
#
# **Baseline Control vs. GT 'CEBPB'**
#     Pearson Correlation: 0.3965
#     Cosine Similarity:   0.6556
#
# **Baseline Control vs. GT 'CEBPE'**
#     Pearson Correlation: 0.4290
#     Cosine Similarity:   0.6957
#
# **Baseline Control vs. GT 'CELF2'**
#     Pearson Correlation: 0.4317
#     Cosine Similarity:   0.6752
#
# **Baseline Control vs. GT 'CITED1'**
#     Pearson Correlation: 0.3553
#     Cosine Similarity:   0.6166
#
# **Baseline Control vs. GT 'CKS1B'**
#     Pearson Correlation: 0.3898
#     Cosine Similarity:   0.6151
#
# **Baseline Control vs. GT 'CLDN6'**
#     Pearson Correlation: 0.3951
#     Cosine Similarity:   0.6424
#
# **Baseline Control vs. GT 'CNN1'**
#     Pearson Correlation: 0.3939
#     Cosine Similarity:   0.6127
#
# **Baseline Control vs. GT 'CNNM4'**
#     Pearson Correlation: 0.4281
#     Cosine Similarity:   0.6496
#
# **Baseline Control vs. GT 'COL1A1'**
#     Pearson Correlation: 0.3999
#     Cosine Similarity:   0.6412
#
# **Baseline Control vs. GT 'COL2A1'**
#     Pearson Correlation: 0.4006
#     Cosine Similarity:   0.6489
#
# **Baseline Control vs. GT 'CSRNP1'**
#     Pearson Correlation: 0.4279
#     Cosine Similarity:   0.6555
#
# **Baseline Control vs. GT 'DLX2'**
#     Pearson Correlation: 0.4104
#     Cosine Similarity:   0.6463
#
# **Baseline Control vs. GT 'DUSP9'**
#     Pearson Correlation: 0.4780
#     Cosine Similarity:   0.6998
#
# **Baseline Control vs. GT 'EGR1'**
#     Pearson Correlation: 0.4083
#     Cosine Similarity:   0.6370
#
# **Baseline Control vs. GT 'ELMSAN1'**
#     Pearson Correlation: 0.4236
#     Cosine Similarity:   0.6480
#
# **Baseline Control vs. GT 'ETS2'**
#     Pearson Correlation: 0.4340
#     Cosine Similarity:   0.6544
#
# **Baseline Control vs. GT 'FEV'**
#     Pearson Correlation: 0.3830
#     Cosine Similarity:   0.6004
#
# **Baseline Control vs. GT 'FOSB'**
#     Pearson Correlation: 0.4621
#     Cosine Similarity:   0.7001
#
# **Baseline Control vs. GT 'FOXA1'**
#     Pearson Correlation: 0.4278
#     Cosine Similarity:   0.6667
#
# **Baseline Control vs. GT 'FOXA3'**
#     Pearson Correlation: 0.4334
#     Cosine Similarity:   0.6732
#
# **Baseline Control vs. GT 'FOXF1'**
#     Pearson Correlation: 0.4416
#     Cosine Similarity:   0.6675
#
# **Baseline Control vs. GT 'FOXL2'**
#     Pearson Correlation: 0.4124
#     Cosine Similarity:   0.6455
#
# **Baseline Control vs. GT 'FOXO4'**
#     Pearson Correlation: 0.3649
#     Cosine Similarity:   0.6171
#
# **Baseline Control vs. GT 'GLB1L2'**
#     Pearson Correlation: 0.4342
#     Cosine Similarity:   0.6688
#
# **Baseline Control vs. GT 'HES7'**
#     Pearson Correlation: 0.3429
#     Cosine Similarity:   0.6005
#
# **Baseline Control vs. GT 'HK2'**
#     Pearson Correlation: 0.4046
#     Cosine Similarity:   0.6263
#
# **Baseline Control vs. GT 'HNF4A'**
#     Pearson Correlation: 0.3846
#     Cosine Similarity:   0.6284
#
# **Baseline Control vs. GT 'HOXA13'**
#     Pearson Correlation: 0.3841
#     Cosine Similarity:   0.6400
#
# **Baseline Control vs. GT 'HOXB9'**
#     Pearson Correlation: 0.4043
#     Cosine Similarity:   0.6601
#
# **Baseline Control vs. GT 'HOXC13'**
#     Pearson Correlation: 0.3500
#     Cosine Similarity:   0.6092
#
# **Baseline Control vs. GT 'IGDCC3'**
#     Pearson Correlation: 0.3941
#     Cosine Similarity:   0.6407
#
# **Baseline Control vs. GT 'IKZF3'**
#     Pearson Correlation: 0.3908
#     Cosine Similarity:   0.6579
#
# **Baseline Control vs. GT 'IRF1'**
#     Pearson Correlation: 0.4246
#     Cosine Similarity:   0.6766
#
# **Baseline Control vs. GT 'ISL2'**
#     Pearson Correlation: 0.4033
#     Cosine Similarity:   0.6290
#
# **Baseline Control vs. GT 'JUN'**
#     Pearson Correlation: 0.4016
#     Cosine Similarity:   0.6306
#
# **Baseline Control vs. GT 'KIF18B'**
#     Pearson Correlation: 0.3992
#     Cosine Similarity:   0.6255
#
# **Baseline Control vs. GT 'KIF2C'**
#     Pearson Correlation: 0.3967
#     Cosine Similarity:   0.6292
#
# **Baseline Control vs. GT 'KLF1'**
#     Pearson Correlation: 0.5041
#     Cosine Similarity:   0.7280
#
# **Baseline Control vs. GT 'KMT2A'**
#     Pearson Correlation: 0.3909
#     Cosine Similarity:   0.6097
#
# **Baseline Control vs. GT 'LHX1'**
#     Pearson Correlation: 0.3981
#     Cosine Similarity:   0.6565
#
# **Baseline Control vs. GT 'LYL1'**
#     Pearson Correlation: 0.4218
#     Cosine Similarity:   0.6498
#
# **Baseline Control vs. GT 'MAML2'**
#     Pearson Correlation: 0.4486
#     Cosine Similarity:   0.6713
#
# **Baseline Control vs. GT 'MAP2K3'**
#     Pearson Correlation: 0.4343
#     Cosine Similarity:   0.6694
#
# **Baseline Control vs. GT 'MAP2K6'**
#     Pearson Correlation: 0.4188
#     Cosine Similarity:   0.6510
#
# **Baseline Control vs. GT 'MAP4K3'**
#     Pearson Correlation: 0.4065
#     Cosine Similarity:   0.6387
#
# **Baseline Control vs. GT 'MAP4K5'**
#     Pearson Correlation: 0.4060
#     Cosine Similarity:   0.6337
#
# **Baseline Control vs. GT 'MAP7D1'**
#     Pearson Correlation: 0.4037
#     Cosine Similarity:   0.6389
#
# **Baseline Control vs. GT 'MAPK1'**
#     Pearson Correlation: 0.4169
#     Cosine Similarity:   0.6354
#
# **Baseline Control vs. GT 'MEIS1'**
#     Pearson Correlation: 0.4104
#     Cosine Similarity:   0.6407
#
# **Baseline Control vs. GT 'MIDN'**
#     Pearson Correlation: 0.3875
#     Cosine Similarity:   0.6464
#
# **Baseline Control vs. GT 'NCL'**
#     Pearson Correlation: 0.3763
#     Cosine Similarity:   0.6155
#
# **Baseline Control vs. GT 'NIT1'**
#     Pearson Correlation: 0.4127
#     Cosine Similarity:   0.6409
#
# **Baseline Control vs. GT 'OSR2'**
#     Pearson Correlation: 0.4429
#     Cosine Similarity:   0.6901
#
# **Baseline Control vs. GT 'PLK4'**
#     Pearson Correlation: 0.3581
#     Cosine Similarity:   0.5880
#
# **Baseline Control vs. GT 'POU3F2'**
#     Pearson Correlation: 0.4097
#     Cosine Similarity:   0.6342
#
# **Baseline Control vs. GT 'PRDM1'**
#     Pearson Correlation: 0.3978
#     Cosine Similarity:   0.6336
#
# **Baseline Control vs. GT 'PRTG'**
#     Pearson Correlation: 0.3987
#     Cosine Similarity:   0.6480
#
# **Baseline Control vs. GT 'PTPN1'**
#     Pearson Correlation: 0.4022
#     Cosine Similarity:   0.6450
#
# **Baseline Control vs. GT 'PTPN12'**
#     Pearson Correlation: 0.3725
#     Cosine Similarity:   0.6082
#
# **Baseline Control vs. GT 'PTPN13'**
#     Pearson Correlation: 0.3903
#     Cosine Similarity:   0.6273
#
# **Baseline Control vs. GT 'PTPN9'**
#     Pearson Correlation: 0.3773
#     Cosine Similarity:   0.5995
#
# **Baseline Control vs. GT 'RREB1'**
#     Pearson Correlation: 0.4036
#     Cosine Similarity:   0.6350
#
# **Baseline Control vs. GT 'RUNX1T1'**
#     Pearson Correlation: 0.4082
#     Cosine Similarity:   0.6316
#
# **Baseline Control vs. GT 'S1PR2'**
#     Pearson Correlation: 0.4417
#     Cosine Similarity:   0.6751
#
# **Baseline Control vs. GT 'SAMD1'**
#     Pearson Correlation: 0.3896
#     Cosine Similarity:   0.6435
#
# **Baseline Control vs. GT 'SET'**
#     Pearson Correlation: 0.4726
#     Cosine Similarity:   0.6906
#
# **Baseline Control vs. GT 'SGK1'**
#     Pearson Correlation: 0.4395
#     Cosine Similarity:   0.6674
#
# **Baseline Control vs. GT 'SLC4A1'**
#     Pearson Correlation: 0.5012
#     Cosine Similarity:   0.7210
#
# **Baseline Control vs. GT 'SLC6A9'**
#     Pearson Correlation: 0.4551
#     Cosine Similarity:   0.6834
#
# **Baseline Control vs. GT 'SNAI1'**
#     Pearson Correlation: 0.3809
#     Cosine Similarity:   0.6297
#
# **Baseline Control vs. GT 'SPI1'**
#     Pearson Correlation: 0.3535
#     Cosine Similarity:   0.6119
#
# **Baseline Control vs. GT 'STIL'**
#     Pearson Correlation: 0.3770
#     Cosine Similarity:   0.6089
#
# **Baseline Control vs. GT 'TBX2'**
#     Pearson Correlation: 0.3986
#     Cosine Similarity:   0.6429
#
# **Baseline Control vs. GT 'TBX3'**
#     Pearson Correlation: 0.4119
#     Cosine Similarity:   0.6450
#
# **Baseline Control vs. GT 'TGFBR2'**
#     Pearson Correlation: 0.3785
#     Cosine Similarity:   0.6131
#
# **Baseline Control vs. GT 'TMSB4X'**
#     Pearson Correlation: 0.4453
#     Cosine Similarity:   0.6708
#
# **Baseline Control vs. GT 'TP73'**
#     Pearson Correlation: 0.3611
#     Cosine Similarity:   0.6364
#
# **Baseline Control vs. GT 'TSC22D1'**
#     Pearson Correlation: 0.4395
#     Cosine Similarity:   0.6614
#
# **Baseline Control vs. GT 'UBASH3A'**
#     Pearson Correlation: 0.4008
#     Cosine Similarity:   0.6533
#
# **Baseline Control vs. GT 'UBASH3B'**
#     Pearson Correlation: 0.4438
#     Cosine Similarity:   0.6640
#
# **Baseline Control vs. GT 'ZBTB1'**
#     Pearson Correlation: 0.4142
#     Cosine Similarity:   0.6494
#
# **Baseline Control vs. GT 'ZBTB10'**
#     Pearson Correlation: 0.3572
#     Cosine Similarity:   0.6176
#
# **Baseline Control vs. GT 'ZBTB25'**
#     Pearson Correlation: 0.4165
#     Cosine Similarity:   0.6426
#
# **Baseline Control vs. GT 'ZC3HAV1'**
#     Pearson Correlation: 0.4428
#     Cosine Similarity:   0.6631
#
# **Baseline Control vs. GT 'ZNF318'**
#     Pearson Correlation: 0.4589
#     Cosine Similarity:   0.6887
# -----------------------------------

# %%
gears_mech.node_map_pert["ZBTB25"]
# Out:
# 9164

# %%
import json
with open("pred_pertvs_pert.json","w") as fp:
    json.dump(gt_results,fp)
